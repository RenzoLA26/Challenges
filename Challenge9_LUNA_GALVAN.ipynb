# %% [markdown]
# <a href="https://colab.research.google.com/github/RenzoLA26/Challenges/blob/main/Challenge9_LUNA_GALVAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style='background:#8B0000; padding:20px; border-radius:8px; margin-bottom:10px'>
# <h1 style='color:white; margin:0'>Challenge 9 — Deep Learning III</h1>
# <h2 style='color:white; margin:0'>Generative Adversarial Networks (GAN) para imágenes biomédicas sintéticas</h2>
# <p style='color:white; margin:0'><b>Curso:</b> Reconocimiento de Patrones — Ingeniería Biomédica</p>
# <p style='color:white; margin:0'>
# </div>

# %% [markdown]
# ## Contexto clínico
#
# En imágenes biomédicas, los modelos generativos pueden utilizarse para **aumentar datos**, explorar variabilidad morfológica o crear datos sintéticos cuando el acceso a imágenes reales es limitado por privacidad, costo o disponibilidad.
#
# En este challenge trabajaremos con un conjunto **sintético y autocontenido** de imágenes tipo células/nódulos de baja resolución. La idea no es generar imágenes clínicas listas para diagnóstico, sino comprender el mecanismo básico de una **GAN**:
#
# - un **Generador (G)** aprende a producir imágenes falsas;
# - un **Discriminador (D)** aprende a distinguir imágenes reales de imágenes generadas;
# - ambos modelos se entrenan en competencia mediante una pérdida adversarial.

# %% [markdown]
# ## Resultados de aprendizaje
#
# Al finalizar el challenge, el estudiante debe ser capaz de:
#
# 1. Explicar la diferencia entre un modelo discriminativo y un modelo generativo.
# 2. Identificar los componentes de una GAN: generador, discriminador, ruido latente y pérdida adversarial.
# 3. Implementar una GAN simple en PyTorch para imágenes biomédicas sintéticas.
# 4. Interpretar curvas de pérdida, muestras generadas y señales de entrenamiento inestable.
# 5. Discutir limitaciones éticas y clínicas del uso de imágenes sintéticas en salud.
#
# ---
#
# ## Distribución sugerida
#
# **Parte in-class:**
# - Concepto de GAN.
# - Generación del dataset sintético.
# - Arquitectura de G y D.
# - Primeras épocas de entrenamiento.
#
# **Parte at-home:**
# - Ejecutar entrenamiento completo.
# - Analizar imágenes generadas.
# - Comparar estadísticas reales vs generadas.
# - Reflexionar sobre riesgos clínicos y posibles usos.

# %% [markdown]
# ---
#
# ## 1. Diseño conceptual
#
# ### 1.1 — ¿Qué problema resuelve una GAN?
#
# **Pregunta C1:** Explica brevemente qué intenta aprender una GAN.
#
# Respuesta:
# .Las características que definen a los datos del mundo real, para luego ser utilizadas para reforzar el aprendizaje en otros modelos como por ejemplo los  de clasificación cuando los datos de entrenamiento no son suficientes o hay desbalance de clases.
#
# ### 1.2 — Componentes principales
#
# Completa la tabla:
#
# | Componente | Rol |
# |---|---|
# | Ruido latente `z` | .Sirve como semilla o inicio para generar un dato arbitrario. |
# | Generador `G(z)` | .Produce un dato a partir de una entrada arbitraria. |
# | Discriminador `D(x)` | .Clasifica un dato como verdadero o falso. |
# | Pérdida adversarial | .La función de pérdida en la que se basará la optimización tanto del G y D. |
#
# ### 1.3 — Interpretación biomédica
#
# **Pregunta C2:** ¿Por qué una imagen biomédica sintética no debe usarse automáticamente como evidencia clínica?
#
# Respuesta:
# .Debido a que no es una representación de la realidad, es ficticia, y su principal utilidad es la de reforzar el aprendizaje de forma general sacrificando la precisión y atención al detalle. Además de esto, existe la posibilidad de sobreajuste y sesgo.

# %% [markdown]
# ---
# ## 2.1 — Librerías y configuración

# %%
# ── Estilo visual y configuración general ────────────────────────────────
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

torch.set_num_threads(1)

UPCH_RED = '#8B0000'

def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

seed_everything(42)

# TODO 1: selecciona el dispositivo de ejecución.
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"

print("Device:", device)
print("PyTorch:", torch.__version__)
# Out:
# Device: cuda
# PyTorch: 2.11.0+cu128

# %% [markdown]
# ---
#
# ## 2. Dataset sintético autocontenido
#
# Generaremos imágenes `28 x 28` con patrones suaves tipo célula/nódulo.
# Cada imagen tendrá una o más regiones brillantes, variabilidad de forma e intensidad, y ruido leve.
#
# Este dataset cumple dos objetivos:
#
# 1. Evitar descarga de datos externos.
# 2. Permitir que la GAN aprenda una distribución visual simple en poco tiempo.

# %%
def generate_synthetic_biomedical_images(n_samples=256, img_size=28, seed=42):
    rng = np.random.default_rng(seed)
    xs = np.linspace(-1, 1, img_size)
    yy, xx = np.meshgrid(xs, xs)
    images = []

    for _ in range(n_samples):
        img = np.zeros((img_size, img_size), dtype=np.float32)

        n_blobs = rng.integers(1, 3)
        for _ in range(n_blobs):
            cx, cy = rng.uniform(-0.30, 0.30, size=2)
            sx, sy = rng.uniform(0.09, 0.22, size=2)
            amp = rng.uniform(0.60, 1.00)
            blob = amp * np.exp(-(((xx - cx) ** 2) / (2 * sx ** 2) +
                                  ((yy - cy) ** 2) / (2 * sy ** 2)))
            img += blob

        if rng.random() < 0.60:
            cx, cy = rng.uniform(-0.20, 0.20, size=2)
            s = rng.uniform(0.35, 0.50)
            halo = 0.20 * np.exp(-(((xx - cx) ** 2 + (yy - cy) ** 2) / (2 * s ** 2)))
            img += halo

        img += rng.normal(0, 0.04, size=(img_size, img_size))

        # TODO 2: normaliza cada imagen al rango [0, 1].
        img = img-np.min(img)
        img = img/np.max(img)

        images.append(img.astype(np.float32))

    # TODO 3: convierte la lista a un arreglo con forma (N, C, H, W).
    X = np.array([[image] for image in images])
    return X

X_real = generate_synthetic_biomedical_images(n_samples=256, img_size=28, seed=42)

print("Forma del dataset:", X_real.shape)
print("Rango de intensidades:", X_real.min(), "a", X_real.max())
# Out:
# Forma del dataset: (256, 1, 28, 28)
# Rango de intensidades: 0.0 a 1.0

# %% [markdown]
# ### Paso 2.1 — Visualización del dataset real sintético

# %%
def show_image_grid(images, title="", n=16, cmap="gray"):
    images = images[:n]
    ncols = 4
    nrows = int(np.ceil(n / ncols))
    plt.figure(figsize=(7, 7))
    for i, img in enumerate(images):
        plt.subplot(nrows, ncols, i + 1)
        if isinstance(img, torch.Tensor):
            img = img.detach().cpu().numpy()
        img = np.squeeze(img)
        plt.imshow(img, cmap=cmap, vmin=0, vmax=1)
        plt.axis("off")
    plt.suptitle(title, fontsize=13)
    plt.tight_layout()
    plt.show()

show_image_grid(X_real, title="Imágenes biomédicas sintéticas reales", n=16)

# %% [markdown]
# ### Paso 2.2 — Normalización para GAN y DataLoader
#
# El generador usará `tanh`, por lo que sus imágenes estarán en el rango `[-1, 1]`.
# Para entrenar de forma consistente, también transformaremos las imágenes reales de `[0, 1]` a `[-1, 1]`:
#
# \[
# x_{gan} = 2x - 1
# \]

# %%
# ── Normalización para GAN ───────────────────────────────────────────────

# TODO 4: transforma las imágenes reales de [0, 1] a [-1, 1].
X_gan = (X_real-0.5)*2

# TODO 5: convierte X_gan a tensor float32.
X_tensor = torch.from_numpy(X_gan,)

# TODO 6: crea TensorDataset para entrenamiento no supervisado.
dataset = TensorDataset(X_tensor)

batch_size = 32
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)

real_batch = next(iter(train_loader))[0]
print("Batch:", real_batch.shape)
print("Rango batch:", real_batch.min().item(), "a", real_batch.max().item())
# Out:
# Batch: torch.Size([32, 1, 28, 28])
# Rango batch: -1.0 a 1.0

# %% [markdown]
# ---
#
# ## 3. Arquitectura GAN
#
# Usaremos una GAN simple con capas totalmente conectadas.
# Esto permite concentrarnos en la lógica adversarial sin sobrecargar el challenge con una DCGAN completa.
#
# ### Generador
#
# Entrada: vector latente `z` de dimensión 16.
# Salida: imagen generada `1 x 28 x 28`.
#
# ### Discriminador
#
# Entrada: imagen `1 x 28 x 28`.
# Salida: un **logit**. No usamos `sigmoid` en el modelo porque `BCEWithLogitsLoss` ya la incorpora internamente.

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim=16, img_size=28):
        super().__init__()
        self.img_size = img_size
        self.net = nn.Sequential(
            # TODO 7: completa la primera capa del generador según la descripción de la arquitectura.
            nn.Linear(16, 28*28),
            nn.ReLU(inplace=True),

            # TODO 8: completa la segunda capa oculta.
            nn.Linear(28*28, 28*28),
            nn.ReLU(inplace=True),

            # TODO 9: completa la capa de salida.
            nn.Linear(28*28, 28*28),

            # TODO 10: completa la activación final del generador.
            nn.Tanh()
        )

    def forward(self, z):
        x = self.net(z)

        # TODO 11: reordena la salida a forma de imagen.
        x = x.view(32, 1, 28, 28)
        return x


class Discriminator(nn.Module):
    def __init__(self, img_size=28):
        super().__init__()
        self.net = nn.Sequential(
            nn.Flatten(),

            # TODO 12: completa la primera capa del discriminador.
            nn.Linear(28*28, 28*28),
            nn.LeakyReLU(0.2, inplace=True),

            # TODO 13: completa la salida del discriminador.
            nn.Linear(28*28, 1)
        )

    def forward(self, x):
        logits = self.net(x).squeeze(1)
        return logits


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


latent_dim = 16
G = Generator(latent_dim=latent_dim).to(device)
D = Discriminator().to(device)

print(G)
print(D)
print("Parámetros G:", count_parameters(G))
print("Parámetros D:", count_parameters(D))
# Out:
# Generator(
#   (net): Sequential(
#     (0): Linear(in_features=16, out_features=784, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=784, out_features=784, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=784, out_features=784, bias=True)
#     (5): Tanh()
#   )
# )
# Discriminator(
#   (net): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=784, bias=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Linear(in_features=784, out_features=1, bias=True)
#   )
# )
# Parámetros G: 1244208
# Parámetros D: 616225

# %% [markdown]
# ---
#
# ## 4. Entrenamiento adversarial
#
# En cada batch realizaremos dos pasos:
#
# 1. **Actualizar el discriminador:**
#    aprende a clasificar imágenes reales como reales e imágenes generadas como falsas.
#
# 2. **Actualizar el generador:**
#    aprende a producir imágenes que el discriminador clasifique como reales.
#
# Usaremos `BCEWithLogitsLoss`, porque el discriminador entrega logits.

# %%
# ── Función de pérdida y optimizadores ──────────────────────────────────

# TODO 14: define la pérdida adversarial para logits binarios.
loss_fn = nn.BCEWithLogitsLoss()

# TODO 15: define optimizadores para G y D.
optimizer_G = optim.Adam(G.parameters(), lr=1e-4)
optimizer_D = optim.Adam(D.parameters(), lr=1e-1)

history = {
    "g_loss": [],
    "d_loss": [],
    "d_real_score": [],
    "d_fake_score": []
}

def train_gan(G, D, train_loader, epochs=8, latent_dim=16, device="cpu"):
    for epoch in range(1, epochs + 1):
        g_losses, d_losses = [], []
        d_real_scores, d_fake_scores = [], []

        for (real_imgs,) in train_loader:
            real_imgs = real_imgs.to(device)
            batch_size = real_imgs.size(0)

            # ------------------------------------------------------------
            # 1) Entrenar Discriminador
            # ------------------------------------------------------------

            # TODO 16: genera imágenes falsas para entrenar el discriminador.
            z = torch.rand((batch_size,16), device=device)
            with torch.no_grad():
              fake_imgs = G.forward(z)

            real_labels = torch.full((batch_size,), 0.9, device=device)
            fake_labels = torch.zeros(batch_size, device=device)

            # TODO 17: calcula logits para imágenes reales y falsas.
            real_logits = D.forward(real_imgs)
            fake_logits = D.forward(fake_imgs)

            d_loss_real = loss_fn(real_logits, real_labels)
            d_loss_fake = loss_fn(fake_logits, fake_labels)
            d_loss = d_loss_real + d_loss_fake

            optimizer_D.zero_grad()

            # TODO 18: ejecuta backpropagation y actualización del discriminador.
            d_loss.backward()
            optimizer_D.step()

            # ------------------------------------------------------------
            # 2) Entrenar Generador
            # ------------------------------------------------------------

            # TODO 19: genera nuevas imágenes falsas y evalúalas con el discriminador.
            z = torch.rand((batch_size,16), device=device)
            fake_imgs = G.forward(z)
            fake_logits = D.forward(fake_imgs)

            target_real = torch.ones(batch_size, device=device)

            # TODO 20: calcula la pérdida del generador.
            g_loss = loss_fn(fake_logits,target_real)

            optimizer_G.zero_grad()

            # TODO 21: ejecuta backpropagation y actualización del generador.
            g_loss.backward()
            optimizer_G.step()

            g_losses.append(g_loss.item())
            d_losses.append(d_loss.item())
            d_real_scores.append(torch.sigmoid(real_logits).mean().item())
            d_fake_scores.append(torch.sigmoid(fake_logits).mean().item())

        history["g_loss"].append(np.mean(g_losses))
        history["d_loss"].append(np.mean(d_losses))
        history["d_real_score"].append(np.mean(d_real_scores))
        history["d_fake_score"].append(np.mean(d_fake_scores))

        print(
            f"Epoch {epoch:02d} | "
            f"D loss: {history['d_loss'][-1]:.3f} | "
            f"G loss: {history['g_loss'][-1]:.3f} | "
            f"D(real): {history['d_real_score'][-1]:.3f} | "
            f"D(fake): {history['d_fake_score'][-1]:.3f}"
        )

train_gan(G, D, train_loader, epochs=2000, latent_dim=latent_dim, device=device)
# Out:
# Epoch 01 | D loss: 451.163 | G loss: 90.381 | D(real): 0.818 | D(fake): 0.001
# Epoch 02 | D loss: 115.419 | G loss: 29.347 | D(real): 0.840 | D(fake): 0.370
# Epoch 03 | D loss: 54.690 | G loss: 26.896 | D(real): 0.750 | D(fake): 0.359
# Epoch 04 | D loss: 109.552 | G loss: 66.446 | D(real): 0.845 | D(fake): 0.007
# Epoch 05 | D loss: 134.299 | G loss: 32.351 | D(real): 0.861 | D(fake): 0.500
# Epoch 06 | D loss: 65.898 | G loss: 25.357 | D(real): 0.889 | D(fake): 0.205
# Epoch 07 | D loss: 47.322 | G loss: 82.458 | D(real): 0.804 | D(fake): 0.000
# Epoch 08 | D loss: 38.018 | G loss: 90.405 | D(real): 0.895 | D(fake): 0.064
# Epoch 09 | D loss: 40.902 | G loss: 418.698 | D(real): 0.898 | D(fake): 0.000
# Epoch 10 | D loss: 61.638 | G loss: 220.617 | D(real): 0.895 | D(fake): 0.004
# Epoch 11 | D loss: 94.183 | G loss: 188.086 | D(real): 0.875 | D(fake): 0.000
# Epoch 12 | D loss: 78.434 | G loss: 142.411 | D(real): 0.871 | D(fake): 0.155
# Epoch 13 | D loss: 94.383 | G loss: 487.075 | D(real): 0.883 | D(fake): 0.000
# Epoch 14 | D loss: 128.026 | G loss: 138.711 | D(real): 0.875 | D(fake): 0.117
# Epoch 15 | D loss: 97.206 | G loss: 194.256 | D(real): 0.891 | D(fake): 0.000
# Epoch 16 | D loss: 140.157 | G loss: 116.701 | D(real): 0.859 | D(fake): 0.125
# Epoch 17 | D loss: 119.262 | G loss: 291.911 | D(real): 0.949 | D(fake): 0.126
# Epoch 18 | D loss: 53.348 | G loss: 376.098 | D(real): 0.901 | D(fake): 0.000
# Epoch 19 | D loss: 85.072 | G loss: 68.122 | D(real): 0.875 | D(fake): 0.375
# Epoch 20 | D loss: 91.950 | G loss: 26.504 | D(real): 0.875 | D(fake): 0.332
# Epoch 21 | D loss: 62.212 | G loss: 68.808 | D(real): 0.875 | D(fake): 0.069
# Epoch 22 | D loss: 14.994 | G loss: 198.169 | D(real): 0.871 | D(fake): 0.000
# Epoch 23 | D loss: 47.062 | G loss: 52.975 | D(real): 0.891 | D(fake): 0.323
# Epoch 24 | D loss: 55.665 | G loss: 54.008 | D(real): 0.875 | D(fake): 0.156
# Epoch 25 | D loss: 49.396 | G loss: 54.242 | D(real): 0.754 | D(fake): 0.021
# Epoch 26 | D loss: 54.771 | G loss: 116.556 | D(real): 0.871 | D(fake): 0.046
# Epoch 27 | D loss: 97.834 | G loss: 116.796 | D(real): 0.871 | D(fake): 0.226
# Epoch 28 | D loss: 47.273 | G loss: 81.400 | D(real): 0.906 | D(fake): 0.001
# Epoch 29 | D loss: 59.975 | G loss: 75.841 | D(real): 0.875 | D(fake): 0.145
# Epoch 30 | D loss: 94.979 | G loss: 152.160 | D(real): 0.782 | D(fake): 0.000
# Epoch 31 | D loss: 60.683 | G loss: 106.784 | D(real): 0.859 | D(fake): 0.125
# Epoch 32 | D loss: 88.040 | G loss: 280.137 | D(real): 0.875 | D(fake): 0.034
# Epoch 33 | D loss: 87.907 | G loss: 113.061 | D(real): 0.887 | D(fake): 0.143
# Epoch 34 | D loss: 63.027 | G loss: 93.582 | D(real): 0.805 | D(fake): 0.000
# Epoch 35 | D loss: 94.887 | G loss: 198.013 | D(real): 0.777 | D(fake): 0.145
# Epoch 36 | D loss: 126.083 | G loss: 381.665 | D(real): 0.875 | D(fake): 0.024
# Epoch 37 | D loss: 105.097 | G loss: 303.390 | D(real): 0.874 | D(fake): 0.000
# Epoch 38 | D loss: 162.054 | G loss: 272.655 | D(real): 0.860 | D(fake): 0.250
# Epoch 39 | D loss: 116.199 | G loss: 320.309 | D(real): 0.785 | D(fake): 0.173
# Epoch 40 | D loss: 220.362 | G loss: 468.358 | D(real): 0.867 | D(fake): 0.000
# Epoch 41 | D loss: 62.761 | G loss: 617.609 | D(real): 0.834 | D(fake): 0.000
# Epoch 42 | D loss: 79.052 | G loss: 368.302 | D(real): 0.879 | D(fake): 0.000
# Epoch 43 | D loss: 120.292 | G loss: 499.396 | D(real): 0.870 | D(fake): 0.035
# Epoch 44 | D loss: 170.851 | G loss: 780.228 | D(real): 0.875 | D(fake): 0.000
# Epoch 45 | D loss: 176.482 | G loss: 1376.346 | D(real): 0.875 | D(fake): 0.000
# Epoch 46 | D loss: 66.262 | G loss: 2530.232 | D(real): 0.819 | D(fake): 0.000
# Epoch 47 | D loss: 262.734 | G loss: 1299.694 | D(real): 0.879 | D(fake): 0.000
# Epoch 48 | D loss: 378.887 | G loss: 3124.514 | D(real): 0.852 | D(fake): 0.000
# Epoch 49 | D loss: 701.664 | G loss: 3346.940 | D(real): 0.875 | D(fake): 0.000
# Epoch 50 | D loss: 660.033 | G loss: 3576.577 | D(real): 0.875 | D(fake): 0.000
# Epoch 51 | D loss: 592.943 | G loss: 1360.984 | D(real): 0.852 | D(fake): 0.031
# Epoch 52 | D loss: 454.925 | G loss: 2933.349 | D(real): 0.859 | D(fake): 0.000
# Epoch 53 | D loss: 374.662 | G loss: 1910.796 | D(real): 0.789 | D(fake): 0.000
# Epoch 54 | D loss: 306.610 | G loss: 2328.651 | D(real): 0.910 | D(fake): 0.000
# Epoch 55 | D loss: 525.784 | G loss: 3055.768 | D(real): 0.867 | D(fake): 0.000
# Epoch 56 | D loss: 474.985 | G loss: 3626.075 | D(real): 0.809 | D(fake): 0.047
# Epoch 57 | D loss: 545.682 | G loss: 6140.427 | D(real): 0.875 | D(fake): 0.000
# Epoch 58 | D loss: 628.056 | G loss: 6712.051 | D(real): 0.867 | D(fake): 0.000
# Epoch 59 | D loss: 774.168 | G loss: 7544.483 | D(real): 0.859 | D(fake): 0.000
# Epoch 60 | D loss: 812.937 | G loss: 3174.314 | D(real): 0.855 | D(fake): 0.000
# Epoch 61 | D loss: 317.602 | G loss: 4933.934 | D(real): 0.820 | D(fake): 0.000
# Epoch 62 | D loss: 510.859 | G loss: 5360.251 | D(real): 0.918 | D(fake): 0.070
# Epoch 63 | D loss: 289.891 | G loss: 4355.357 | D(real): 0.856 | D(fake): 0.000
# Epoch 64 | D loss: 655.724 | G loss: 6443.184 | D(real): 0.875 | D(fake): 0.000
# Epoch 65 | D loss: 564.050 | G loss: 3620.176 | D(real): 0.879 | D(fake): 0.000
# Epoch 66 | D loss: 427.599 | G loss: 5895.558 | D(real): 0.855 | D(fake): 0.020
# Epoch 67 | D loss: 181.874 | G loss: 5703.006 | D(real): 0.918 | D(fake): 0.000
# Epoch 68 | D loss: 201.638 | G loss: 3974.944 | D(real): 0.802 | D(fake): 0.000
# Epoch 69 | D loss: 452.723 | G loss: 3357.268 | D(real): 0.875 | D(fake): 0.125
# Epoch 70 | D loss: 445.748 | G loss: 4578.528 | D(real): 0.859 | D(fake): 0.000
# Epoch 71 | D loss: 282.020 | G loss: 1770.444 | D(real): 0.855 | D(fake): 0.000
# Epoch 72 | D loss: 280.122 | G loss: 1159.838 | D(real): 0.670 | D(fake): 0.039
# Epoch 73 | D loss: 130.760 | G loss: 1467.971 | D(real): 0.913 | D(fake): 0.000
# Epoch 74 | D loss: 164.305 | G loss: 1609.819 | D(real): 0.816 | D(fake): 0.012
# Epoch 75 | D loss: 128.917 | G loss: 1647.405 | D(real): 0.936 | D(fake): 0.000
# Epoch 76 | D loss: 1318.230 | G loss: 1175.107 | D(real): 0.629 | D(fake): 0.406
# Epoch 77 | D loss: 816.059 | G loss: 2408.086 | D(real): 0.750 | D(fake): 0.103
# Epoch 78 | D loss: 232.577 | G loss: 1860.104 | D(real): 0.867 | D(fake): 0.000
# Epoch 79 | D loss: 325.099 | G loss: 841.566 | D(real): 0.715 | D(fake): 0.125
# Epoch 80 | D loss: 255.940 | G loss: 1633.476 | D(real): 0.863 | D(fake): 0.004
# Epoch 81 | D loss: 430.263 | G loss: 1730.188 | D(real): 0.723 | D(fake): 0.012
# Epoch 82 | D loss: 1355.195 | G loss: 1153.331 | D(real): 0.527 | D(fake): 0.563
# Epoch 83 | D loss: 1197.138 | G loss: 1237.602 | D(real): 0.735 | D(fake): 0.375
# Epoch 84 | D loss: 693.051 | G loss: 1019.367 | D(real): 0.555 | D(fake): 0.250
# Epoch 85 | D loss: 1884.677 | G loss: 898.564 | D(real): 0.617 | D(fake): 0.500
# Epoch 86 | D loss: 492.193 | G loss: 1628.227 | D(real): 0.750 | D(fake): 0.027
# Epoch 87 | D loss: 251.142 | G loss: 1985.556 | D(real): 0.832 | D(fake): 0.000
# Epoch 88 | D loss: 476.371 | G loss: 1602.018 | D(real): 0.695 | D(fake): 0.141
# Epoch 89 | D loss: 655.497 | G loss: 918.658 | D(real): 0.617 | D(fake): 0.268
# Epoch 90 | D loss: 315.605 | G loss: 1821.968 | D(real): 0.691 | D(fake): 0.000
# Epoch 91 | D loss: 408.988 | G loss: 1474.469 | D(real): 0.746 | D(fake): 0.039
# Epoch 92 | D loss: 324.421 | G loss: 1555.219 | D(real): 0.812 | D(fake): 0.014
# Epoch 93 | D loss: 163.603 | G loss: 2212.645 | D(real): 0.903 | D(fake): 0.000
# Epoch 94 | D loss: 303.645 | G loss: 1529.730 | D(real): 0.777 | D(fake): 0.047
# Epoch 95 | D loss: 365.732 | G loss: 2561.947 | D(real): 0.871 | D(fake): 0.000
# Epoch 96 | D loss: 449.742 | G loss: 1551.937 | D(real): 0.667 | D(fake): 0.031
# Epoch 97 | D loss: 853.222 | G loss: 1145.345 | D(real): 0.488 | D(fake): 0.109
# Epoch 98 | D loss: 517.515 | G loss: 1350.611 | D(real): 0.684 | D(fake): 0.000
# Epoch 99 | D loss: 183.446 | G loss: 1303.301 | D(real): 0.906 | D(fake): 0.000
# Epoch 100 | D loss: 310.081 | G loss: 2010.264 | D(real): 0.754 | D(fake): 0.004
# Epoch 101 | D loss: 265.286 | G loss: 3062.807 | D(real): 0.906 | D(fake): 0.000
# Epoch 102 | D loss: 202.058 | G loss: 2020.319 | D(real): 0.797 | D(fake): 0.000
# Epoch 103 | D loss: 352.048 | G loss: 1214.492 | D(real): 0.680 | D(fake): 0.125
# Epoch 104 | D loss: 1015.400 | G loss: 2492.836 | D(real): 0.750 | D(fake): 0.148
# Epoch 105 | D loss: 343.162 | G loss: 1894.781 | D(real): 0.879 | D(fake): 0.000
# Epoch 106 | D loss: 346.352 | G loss: 1701.622 | D(real): 0.724 | D(fake): 0.094
# Epoch 107 | D loss: 343.959 | G loss: 2001.317 | D(real): 0.832 | D(fake): 0.055
# Epoch 108 | D loss: 390.133 | G loss: 3092.720 | D(real): 0.773 | D(fake): 0.004
# Epoch 109 | D loss: 429.492 | G loss: 2070.824 | D(real): 0.879 | D(fake): 0.000
# Epoch 110 | D loss: 361.861 | G loss: 2327.312 | D(real): 0.738 | D(fake): 0.008
# Epoch 111 | D loss: 460.809 | G loss: 1281.653 | D(real): 0.603 | D(fake): 0.246
# Epoch 112 | D loss: 703.762 | G loss: 2238.143 | D(real): 0.629 | D(fake): 0.016
# Epoch 113 | D loss: 341.907 | G loss: 1373.363 | D(real): 0.730 | D(fake): 0.004
# Epoch 114 | D loss: 1047.436 | G loss: 2680.510 | D(real): 0.547 | D(fake): 0.250
# Epoch 115 | D loss: 416.251 | G loss: 2795.114 | D(real): 1.000 | D(fake): 0.000
# Epoch 116 | D loss: 244.027 | G loss: 3557.825 | D(real): 0.880 | D(fake): 0.000
# Epoch 117 | D loss: 367.006 | G loss: 2189.813 | D(real): 0.653 | D(fake): 0.008
# Epoch 118 | D loss: 407.589 | G loss: 2824.482 | D(real): 0.867 | D(fake): 0.125
# Epoch 119 | D loss: 309.122 | G loss: 2147.675 | D(real): 0.781 | D(fake): 0.008
# Epoch 120 | D loss: 1196.471 | G loss: 1532.234 | D(real): 0.472 | D(fake): 0.141
# Epoch 121 | D loss: 1505.242 | G loss: 829.021 | D(real): 0.445 | D(fake): 0.492
# Epoch 122 | D loss: 1507.729 | G loss: 1515.116 | D(real): 0.570 | D(fake): 0.477
# Epoch 123 | D loss: 556.267 | G loss: 3036.668 | D(real): 0.750 | D(fake): 0.000
# Epoch 124 | D loss: 301.249 | G loss: 2460.034 | D(real): 0.852 | D(fake): 0.000
# Epoch 125 | D loss: 211.893 | G loss: 1430.118 | D(real): 0.781 | D(fake): 0.004
# Epoch 126 | D loss: 356.840 | G loss: 1522.326 | D(real): 0.754 | D(fake): 0.059
# Epoch 127 | D loss: 739.659 | G loss: 2392.414 | D(real): 0.594 | D(fake): 0.230
# Epoch 128 | D loss: 966.126 | G loss: 2143.359 | D(real): 0.641 | D(fake): 0.218
# Epoch 129 | D loss: 507.603 | G loss: 1915.824 | D(real): 0.672 | D(fake): 0.098
# Epoch 130 | D loss: 1442.698 | G loss: 2228.173 | D(real): 0.543 | D(fake): 0.263
# Epoch 131 | D loss: 1950.991 | G loss: 3110.634 | D(real): 0.504 | D(fake): 0.347
# Epoch 132 | D loss: 713.635 | G loss: 4599.102 | D(real): 0.813 | D(fake): 0.000
# Epoch 133 | D loss: 455.843 | G loss: 2417.780 | D(real): 0.882 | D(fake): 0.000
# Epoch 134 | D loss: 247.944 | G loss: 2017.522 | D(real): 0.809 | D(fake): 0.000
# Epoch 135 | D loss: 415.688 | G loss: 2443.346 | D(real): 0.746 | D(fake): 0.086
# Epoch 136 | D loss: 333.777 | G loss: 1253.116 | D(real): 0.817 | D(fake): 0.066
# Epoch 137 | D loss: 1406.434 | G loss: 1650.393 | D(real): 0.457 | D(fake): 0.184
# Epoch 138 | D loss: 1708.242 | G loss: 1954.479 | D(real): 0.461 | D(fake): 0.290
# Epoch 139 | D loss: 648.404 | G loss: 2582.201 | D(real): 0.628 | D(fake): 0.137
# Epoch 140 | D loss: 851.213 | G loss: 3756.596 | D(real): 0.828 | D(fake): 0.000
# Epoch 141 | D loss: 728.294 | G loss: 4692.489 | D(real): 0.812 | D(fake): 0.070
# Epoch 142 | D loss: 752.342 | G loss: 5724.095 | D(real): 0.786 | D(fake): 0.008
# Epoch 143 | D loss: 574.113 | G loss: 5709.665 | D(real): 0.797 | D(fake): 0.020
# Epoch 144 | D loss: 1386.827 | G loss: 3844.074 | D(real): 0.746 | D(fake): 0.250
# Epoch 145 | D loss: 1367.613 | G loss: 4119.892 | D(real): 0.508 | D(fake): 0.153
# Epoch 146 | D loss: 1539.123 | G loss: 2810.489 | D(real): 0.594 | D(fake): 0.375
# Epoch 147 | D loss: 1317.729 | G loss: 2703.221 | D(real): 0.727 | D(fake): 0.297
# Epoch 148 | D loss: 710.170 | G loss: 3421.706 | D(real): 0.691 | D(fake): 0.000
# Epoch 149 | D loss: 334.227 | G loss: 1722.231 | D(real): 0.902 | D(fake): 0.000
# Epoch 150 | D loss: 370.894 | G loss: 1014.961 | D(real): 0.805 | D(fake): 0.125
# Epoch 151 | D loss: 464.338 | G loss: 2328.683 | D(real): 0.688 | D(fake): 0.125
# Epoch 152 | D loss: 403.721 | G loss: 2126.861 | D(real): 0.973 | D(fake): 0.000
# Epoch 153 | D loss: 366.168 | G loss: 2457.921 | D(real): 0.746 | D(fake): 0.004
# Epoch 154 | D loss: 301.795 | G loss: 1868.711 | D(real): 0.883 | D(fake): 0.000
# Epoch 155 | D loss: 201.344 | G loss: 1115.139 | D(real): 0.910 | D(fake): 0.016
# Epoch 156 | D loss: 366.541 | G loss: 1637.241 | D(real): 0.682 | D(fake): 0.004
# Epoch 157 | D loss: 278.146 | G loss: 912.007 | D(real): 0.762 | D(fake): 0.117
# Epoch 158 | D loss: 285.235 | G loss: 944.342 | D(real): 0.801 | D(fake): 0.000
# Epoch 159 | D loss: 159.324 | G loss: 1126.445 | D(real): 0.909 | D(fake): 0.000
# Epoch 160 | D loss: 142.641 | G loss: 1183.616 | D(real): 0.910 | D(fake): 0.000
# Epoch 161 | D loss: 116.542 | G loss: 748.987 | D(real): 0.879 | D(fake): 0.008
# Epoch 162 | D loss: 151.128 | G loss: 844.118 | D(real): 0.863 | D(fake): 0.083
# Epoch 163 | D loss: 462.388 | G loss: 2284.140 | D(real): 0.645 | D(fake): 0.125
# Epoch 164 | D loss: 228.700 | G loss: 1725.676 | D(real): 0.984 | D(fake): 0.000
# Epoch 165 | D loss: 217.508 | G loss: 988.519 | D(real): 0.758 | D(fake): 0.149
# Epoch 166 | D loss: 374.506 | G loss: 627.168 | D(real): 0.648 | D(fake): 0.090
# Epoch 167 | D loss: 306.137 | G loss: 415.851 | D(real): 0.664 | D(fake): 0.172
# Epoch 168 | D loss: 225.811 | G loss: 1049.775 | D(real): 0.742 | D(fake): 0.080
# Epoch 169 | D loss: 135.707 | G loss: 1267.863 | D(real): 0.912 | D(fake): 0.008
# Epoch 170 | D loss: 414.183 | G loss: 1191.805 | D(real): 0.697 | D(fake): 0.242
# Epoch 171 | D loss: 481.835 | G loss: 2334.386 | D(real): 0.687 | D(fake): 0.121
# Epoch 172 | D loss: 438.270 | G loss: 1426.807 | D(real): 0.754 | D(fake): 0.125
# Epoch 173 | D loss: 489.791 | G loss: 1691.098 | D(real): 0.785 | D(fake): 0.250
# Epoch 174 | D loss: 416.014 | G loss: 1672.051 | D(real): 0.656 | D(fake): 0.125
# Epoch 175 | D loss: 264.576 | G loss: 1362.460 | D(real): 0.812 | D(fake): 0.137
# Epoch 176 | D loss: 519.798 | G loss: 1521.586 | D(real): 0.602 | D(fake): 0.129
# Epoch 177 | D loss: 233.043 | G loss: 1257.564 | D(real): 0.886 | D(fake): 0.000
# Epoch 178 | D loss: 278.373 | G loss: 830.272 | D(real): 0.809 | D(fake): 0.107
# Epoch 179 | D loss: 508.438 | G loss: 969.234 | D(real): 0.570 | D(fake): 0.151
# Epoch 180 | D loss: 813.231 | G loss: 1381.098 | D(real): 0.527 | D(fake): 0.332
# Epoch 181 | D loss: 427.823 | G loss: 2315.736 | D(real): 0.816 | D(fake): 0.000
# Epoch 182 | D loss: 368.435 | G loss: 1771.979 | D(real): 0.816 | D(fake): 0.008
# Epoch 183 | D loss: 285.921 | G loss: 1573.684 | D(real): 0.762 | D(fake): 0.016
# Epoch 184 | D loss: 257.867 | G loss: 1554.258 | D(real): 0.848 | D(fake): 0.027
# Epoch 185 | D loss: 247.639 | G loss: 1728.727 | D(real): 0.723 | D(fake): 0.027
# Epoch 186 | D loss: 519.290 | G loss: 1862.193 | D(real): 0.686 | D(fake): 0.141
# Epoch 187 | D loss: 442.681 | G loss: 1682.926 | D(real): 0.688 | D(fake): 0.027
# Epoch 188 | D loss: 543.740 | G loss: 1741.229 | D(real): 0.664 | D(fake): 0.125
# Epoch 189 | D loss: 526.317 | G loss: 1852.038 | D(real): 0.649 | D(fake): 0.031
# Epoch 190 | D loss: 357.903 | G loss: 3324.921 | D(real): 0.712 | D(fake): 0.000
# Epoch 191 | D loss: 358.894 | G loss: 4223.284 | D(real): 0.871 | D(fake): 0.000
# Epoch 192 | D loss: 333.649 | G loss: 2381.707 | D(real): 0.938 | D(fake): 0.004
# Epoch 193 | D loss: 151.705 | G loss: 2198.804 | D(real): 0.902 | D(fake): 0.000
# Epoch 194 | D loss: 269.196 | G loss: 1359.810 | D(real): 0.777 | D(fake): 0.059
# Epoch 195 | D loss: 882.610 | G loss: 2470.642 | D(real): 0.551 | D(fake): 0.258
# Epoch 196 | D loss: 472.593 | G loss: 2094.036 | D(real): 0.863 | D(fake): 0.039
# Epoch 197 | D loss: 822.414 | G loss: 2559.812 | D(real): 0.631 | D(fake): 0.125
# Epoch 198 | D loss: 525.508 | G loss: 1426.420 | D(real): 0.746 | D(fake): 0.230
# Epoch 199 | D loss: 489.072 | G loss: 1745.148 | D(real): 0.680 | D(fake): 0.125
# Epoch 200 | D loss: 297.680 | G loss: 1655.197 | D(real): 0.797 | D(fake): 0.070
# Epoch 201 | D loss: 438.228 | G loss: 2764.201 | D(real): 0.664 | D(fake): 0.082
# Epoch 202 | D loss: 349.708 | G loss: 1713.164 | D(real): 0.977 | D(fake): 0.000
# Epoch 203 | D loss: 226.125 | G loss: 2484.691 | D(real): 0.832 | D(fake): 0.000
# Epoch 204 | D loss: 231.837 | G loss: 1183.485 | D(real): 0.879 | D(fake): 0.004
# Epoch 205 | D loss: 163.128 | G loss: 828.421 | D(real): 0.891 | D(fake): 0.012
# Epoch 206 | D loss: 228.056 | G loss: 659.720 | D(real): 0.770 | D(fake): 0.000
# Epoch 207 | D loss: 290.669 | G loss: 705.278 | D(real): 0.734 | D(fake): 0.129
# Epoch 208 | D loss: 388.586 | G loss: 1656.788 | D(real): 0.707 | D(fake): 0.125
# Epoch 209 | D loss: 326.714 | G loss: 2040.401 | D(real): 0.773 | D(fake): 0.098
# Epoch 210 | D loss: 239.941 | G loss: 1263.704 | D(real): 0.949 | D(fake): 0.000
# Epoch 211 | D loss: 237.265 | G loss: 1425.694 | D(real): 0.730 | D(fake): 0.001
# Epoch 212 | D loss: 259.681 | G loss: 2459.303 | D(real): 0.832 | D(fake): 0.000
# Epoch 213 | D loss: 227.168 | G loss: 1604.822 | D(real): 0.895 | D(fake): 0.000
# Epoch 214 | D loss: 305.343 | G loss: 780.554 | D(real): 0.762 | D(fake): 0.125
# Epoch 215 | D loss: 388.945 | G loss: 939.867 | D(real): 0.699 | D(fake): 0.129
# Epoch 216 | D loss: 294.756 | G loss: 922.828 | D(real): 0.805 | D(fake): 0.004
# Epoch 217 | D loss: 145.364 | G loss: 847.431 | D(real): 0.859 | D(fake): 0.000
# Epoch 218 | D loss: 141.440 | G loss: 1100.910 | D(real): 0.883 | D(fake): 0.031
# Epoch 219 | D loss: 132.585 | G loss: 1543.183 | D(real): 0.883 | D(fake): 0.004
# Epoch 220 | D loss: 147.990 | G loss: 834.530 | D(real): 0.900 | D(fake): 0.020
# Epoch 221 | D loss: 140.809 | G loss: 1182.104 | D(real): 0.890 | D(fake): 0.000
# Epoch 222 | D loss: 139.037 | G loss: 1017.637 | D(real): 0.801 | D(fake): 0.035
# Epoch 223 | D loss: 137.264 | G loss: 1018.348 | D(real): 0.816 | D(fake): 0.008
# Epoch 224 | D loss: 216.723 | G loss: 1519.253 | D(real): 0.800 | D(fake): 0.039
# Epoch 225 | D loss: 253.251 | G loss: 1585.147 | D(real): 0.774 | D(fake): 0.043
# Epoch 226 | D loss: 168.993 | G loss: 996.839 | D(real): 0.871 | D(fake): 0.055
# Epoch 227 | D loss: 127.214 | G loss: 887.888 | D(real): 0.823 | D(fake): 0.085
# Epoch 228 | D loss: 712.883 | G loss: 1979.777 | D(real): 0.621 | D(fake): 0.125
# Epoch 229 | D loss: 320.974 | G loss: 1608.700 | D(real): 0.879 | D(fake): 0.004
# Epoch 230 | D loss: 204.431 | G loss: 1394.208 | D(real): 0.898 | D(fake): 0.000
# Epoch 231 | D loss: 364.306 | G loss: 1112.407 | D(real): 0.660 | D(fake): 0.125
# Epoch 232 | D loss: 238.402 | G loss: 2369.298 | D(real): 0.789 | D(fake): 0.023
# Epoch 233 | D loss: 265.466 | G loss: 1722.581 | D(real): 0.988 | D(fake): 0.000
# Epoch 234 | D loss: 208.161 | G loss: 1528.979 | D(real): 0.859 | D(fake): 0.000
# Epoch 235 | D loss: 125.289 | G loss: 717.096 | D(real): 0.896 | D(fake): 0.000
# Epoch 236 | D loss: 335.049 | G loss: 1429.803 | D(real): 0.641 | D(fake): 0.125
# Epoch 237 | D loss: 427.312 | G loss: 2022.386 | D(real): 0.715 | D(fake): 0.078
# Epoch 238 | D loss: 290.777 | G loss: 1690.275 | D(real): 0.836 | D(fake): 0.125
# Epoch 239 | D loss: 206.627 | G loss: 1329.418 | D(real): 0.809 | D(fake): 0.016
# Epoch 240 | D loss: 185.345 | G loss: 1014.232 | D(real): 0.812 | D(fake): 0.008
# Epoch 241 | D loss: 174.469 | G loss: 1115.441 | D(real): 0.848 | D(fake): 0.011
# Epoch 242 | D loss: 354.091 | G loss: 1213.035 | D(real): 0.738 | D(fake): 0.230
# Epoch 243 | D loss: 275.968 | G loss: 1461.352 | D(real): 0.754 | D(fake): 0.008
# Epoch 244 | D loss: 329.347 | G loss: 1507.028 | D(real): 0.799 | D(fake): 0.125
# Epoch 245 | D loss: 324.579 | G loss: 1677.473 | D(real): 0.809 | D(fake): 0.048
# Epoch 246 | D loss: 212.802 | G loss: 2044.311 | D(real): 0.797 | D(fake): 0.000
# Epoch 247 | D loss: 233.662 | G loss: 1332.869 | D(real): 0.906 | D(fake): 0.000
# Epoch 248 | D loss: 147.707 | G loss: 728.511 | D(real): 0.945 | D(fake): 0.000
# Epoch 249 | D loss: 142.391 | G loss: 779.259 | D(real): 0.832 | D(fake): 0.008
# Epoch 250 | D loss: 180.955 | G loss: 741.437 | D(real): 0.715 | D(fake): 0.026
# Epoch 251 | D loss: 278.311 | G loss: 962.447 | D(real): 0.774 | D(fake): 0.250
# Epoch 252 | D loss: 276.309 | G loss: 1191.012 | D(real): 0.775 | D(fake): 0.105
# Epoch 253 | D loss: 240.254 | G loss: 1017.488 | D(real): 0.780 | D(fake): 0.125
# Epoch 254 | D loss: 273.821 | G loss: 994.702 | D(real): 0.762 | D(fake): 0.125
# Epoch 255 | D loss: 234.674 | G loss: 1352.724 | D(real): 0.793 | D(fake): 0.012
# Epoch 256 | D loss: 182.823 | G loss: 1403.547 | D(real): 0.889 | D(fake): 0.000
# Epoch 257 | D loss: 109.309 | G loss: 744.496 | D(real): 0.910 | D(fake): 0.004
# Epoch 258 | D loss: 90.685 | G loss: 515.515 | D(real): 0.887 | D(fake): 0.000
# Epoch 259 | D loss: 81.889 | G loss: 424.916 | D(real): 0.859 | D(fake): 0.008
# Epoch 260 | D loss: 91.868 | G loss: 364.972 | D(real): 0.836 | D(fake): 0.024
# Epoch 261 | D loss: 87.754 | G loss: 365.357 | D(real): 0.805 | D(fake): 0.076
# Epoch 262 | D loss: 261.107 | G loss: 1419.921 | D(real): 0.636 | D(fake): 0.125
# Epoch 263 | D loss: 323.538 | G loss: 1766.217 | D(real): 0.815 | D(fake): 0.113
# Epoch 264 | D loss: 349.560 | G loss: 1228.679 | D(real): 0.824 | D(fake): 0.031
# Epoch 265 | D loss: 251.566 | G loss: 1346.055 | D(real): 0.809 | D(fake): 0.058
# Epoch 266 | D loss: 222.969 | G loss: 987.324 | D(real): 0.805 | D(fake): 0.028
# Epoch 267 | D loss: 203.676 | G loss: 1000.750 | D(real): 0.799 | D(fake): 0.119
# Epoch 268 | D loss: 209.432 | G loss: 1348.425 | D(real): 0.801 | D(fake): 0.037
# Epoch 269 | D loss: 180.985 | G loss: 1376.913 | D(real): 0.824 | D(fake): 0.000
# Epoch 270 | D loss: 106.089 | G loss: 444.502 | D(real): 0.910 | D(fake): 0.000
# Epoch 271 | D loss: 73.109 | G loss: 399.037 | D(real): 0.902 | D(fake): 0.012
# Epoch 272 | D loss: 97.242 | G loss: 603.635 | D(real): 0.806 | D(fake): 0.043
# Epoch 273 | D loss: 80.474 | G loss: 400.218 | D(real): 0.881 | D(fake): 0.093
# Epoch 274 | D loss: 157.029 | G loss: 769.364 | D(real): 0.828 | D(fake): 0.000
# Epoch 275 | D loss: 138.536 | G loss: 1201.814 | D(real): 0.869 | D(fake): 0.008
# Epoch 276 | D loss: 91.508 | G loss: 879.529 | D(real): 0.879 | D(fake): 0.000
# Epoch 277 | D loss: 71.689 | G loss: 597.909 | D(real): 0.887 | D(fake): 0.004
# Epoch 278 | D loss: 88.312 | G loss: 629.262 | D(real): 0.767 | D(fake): 0.071
# Epoch 279 | D loss: 159.114 | G loss: 1258.509 | D(real): 0.949 | D(fake): 0.000
# Epoch 280 | D loss: 149.733 | G loss: 879.972 | D(real): 0.883 | D(fake): 0.000
# Epoch 281 | D loss: 172.020 | G loss: 606.524 | D(real): 0.703 | D(fake): 0.125
# Epoch 282 | D loss: 338.396 | G loss: 2409.278 | D(real): 0.781 | D(fake): 0.087
# Epoch 283 | D loss: 277.766 | G loss: 794.250 | D(real): 0.965 | D(fake): 0.000
# Epoch 284 | D loss: 192.440 | G loss: 1155.821 | D(real): 0.855 | D(fake): 0.000
# Epoch 285 | D loss: 167.077 | G loss: 621.933 | D(real): 0.791 | D(fake): 0.125
# Epoch 286 | D loss: 253.881 | G loss: 1318.594 | D(real): 0.727 | D(fake): 0.105
# Epoch 287 | D loss: 251.113 | G loss: 874.275 | D(real): 0.859 | D(fake): 0.008
# Epoch 288 | D loss: 150.871 | G loss: 1071.597 | D(real): 0.840 | D(fake): 0.000
# Epoch 289 | D loss: 274.903 | G loss: 841.803 | D(real): 0.738 | D(fake): 0.246
# Epoch 290 | D loss: 213.551 | G loss: 2268.421 | D(real): 0.770 | D(fake): 0.000
# Epoch 291 | D loss: 184.631 | G loss: 578.854 | D(real): 0.977 | D(fake): 0.000
# Epoch 292 | D loss: 89.546 | G loss: 732.036 | D(real): 0.824 | D(fake): 0.044
# Epoch 293 | D loss: 117.996 | G loss: 653.205 | D(real): 0.734 | D(fake): 0.066
# Epoch 294 | D loss: 167.956 | G loss: 892.720 | D(real): 0.844 | D(fake): 0.039
# Epoch 295 | D loss: 144.745 | G loss: 553.692 | D(real): 0.782 | D(fake): 0.027
# Epoch 296 | D loss: 85.927 | G loss: 491.954 | D(real): 0.864 | D(fake): 0.058
# Epoch 297 | D loss: 95.698 | G loss: 369.619 | D(real): 0.792 | D(fake): 0.039
# Epoch 298 | D loss: 221.842 | G loss: 1223.921 | D(real): 0.746 | D(fake): 0.125
# Epoch 299 | D loss: 176.081 | G loss: 686.758 | D(real): 0.957 | D(fake): 0.000
# Epoch 300 | D loss: 139.503 | G loss: 977.386 | D(real): 0.855 | D(fake): 0.000
# Epoch 301 | D loss: 75.666 | G loss: 432.162 | D(real): 0.902 | D(fake): 0.023
# Epoch 302 | D loss: 56.580 | G loss: 581.955 | D(real): 0.890 | D(fake): 0.000
# Epoch 303 | D loss: 56.952 | G loss: 535.357 | D(real): 0.883 | D(fake): 0.008
# Epoch 304 | D loss: 54.594 | G loss: 473.170 | D(real): 0.910 | D(fake): 0.008
# Epoch 305 | D loss: 39.289 | G loss: 373.635 | D(real): 0.893 | D(fake): 0.016
# Epoch 306 | D loss: 55.809 | G loss: 365.710 | D(real): 0.887 | D(fake): 0.031
# Epoch 307 | D loss: 76.427 | G loss: 342.770 | D(real): 0.888 | D(fake): 0.012
# Epoch 308 | D loss: 106.535 | G loss: 521.081 | D(real): 0.711 | D(fake): 0.161
# Epoch 309 | D loss: 169.981 | G loss: 998.948 | D(real): 0.809 | D(fake): 0.000
# Epoch 310 | D loss: 118.156 | G loss: 450.574 | D(real): 0.934 | D(fake): 0.013
# Epoch 311 | D loss: 83.496 | G loss: 294.652 | D(real): 0.789 | D(fake): 0.090
# Epoch 312 | D loss: 75.989 | G loss: 424.547 | D(real): 0.871 | D(fake): 0.006
# Epoch 313 | D loss: 65.814 | G loss: 366.036 | D(real): 0.883 | D(fake): 0.053
# Epoch 314 | D loss: 107.562 | G loss: 779.547 | D(real): 0.732 | D(fake): 0.125
# Epoch 315 | D loss: 178.077 | G loss: 819.062 | D(real): 0.825 | D(fake): 0.125
# Epoch 316 | D loss: 181.464 | G loss: 931.935 | D(real): 0.772 | D(fake): 0.039
# Epoch 317 | D loss: 102.749 | G loss: 791.772 | D(real): 0.847 | D(fake): 0.000
# Epoch 318 | D loss: 45.101 | G loss: 256.012 | D(real): 0.888 | D(fake): 0.020
# Epoch 319 | D loss: 42.316 | G loss: 451.920 | D(real): 0.899 | D(fake): 0.000
# Epoch 320 | D loss: 46.585 | G loss: 302.683 | D(real): 0.829 | D(fake): 0.055
# Epoch 321 | D loss: 38.133 | G loss: 323.878 | D(real): 0.887 | D(fake): 0.012
# Epoch 322 | D loss: 37.744 | G loss: 260.594 | D(real): 0.849 | D(fake): 0.008
# Epoch 323 | D loss: 55.414 | G loss: 333.004 | D(real): 0.815 | D(fake): 0.077
# Epoch 324 | D loss: 78.789 | G loss: 341.506 | D(real): 0.937 | D(fake): 0.020
# Epoch 325 | D loss: 55.567 | G loss: 411.676 | D(real): 0.861 | D(fake): 0.039
# Epoch 326 | D loss: 67.094 | G loss: 431.596 | D(real): 0.824 | D(fake): 0.031
# Epoch 327 | D loss: 47.326 | G loss: 369.893 | D(real): 0.867 | D(fake): 0.000
# Epoch 328 | D loss: 76.857 | G loss: 321.051 | D(real): 0.839 | D(fake): 0.062
# Epoch 329 | D loss: 82.968 | G loss: 619.172 | D(real): 0.852 | D(fake): 0.000
# Epoch 330 | D loss: 62.452 | G loss: 361.213 | D(real): 0.876 | D(fake): 0.038
# Epoch 331 | D loss: 52.712 | G loss: 306.508 | D(real): 0.892 | D(fake): 0.002
# Epoch 332 | D loss: 73.982 | G loss: 291.343 | D(real): 0.750 | D(fake): 0.080
# Epoch 333 | D loss: 143.029 | G loss: 599.166 | D(real): 0.953 | D(fake): 0.004
# Epoch 334 | D loss: 145.366 | G loss: 850.569 | D(real): 0.857 | D(fake): 0.000
# Epoch 335 | D loss: 93.463 | G loss: 359.388 | D(real): 0.785 | D(fake): 0.122
# Epoch 336 | D loss: 101.061 | G loss: 292.284 | D(real): 0.897 | D(fake): 0.000
# Epoch 337 | D loss: 103.081 | G loss: 467.817 | D(real): 0.880 | D(fake): 0.000
# Epoch 338 | D loss: 68.859 | G loss: 188.924 | D(real): 0.755 | D(fake): 0.136
# Epoch 339 | D loss: 108.944 | G loss: 572.750 | D(real): 0.823 | D(fake): 0.067
# Epoch 340 | D loss: 166.821 | G loss: 1003.050 | D(real): 0.760 | D(fake): 0.117
# Epoch 341 | D loss: 128.808 | G loss: 882.626 | D(real): 0.818 | D(fake): 0.000
# Epoch 342 | D loss: 85.426 | G loss: 344.373 | D(real): 0.808 | D(fake): 0.081
# Epoch 343 | D loss: 89.814 | G loss: 653.618 | D(real): 0.847 | D(fake): 0.000
# Epoch 344 | D loss: 76.312 | G loss: 589.893 | D(real): 0.883 | D(fake): 0.000
# Epoch 345 | D loss: 54.007 | G loss: 191.356 | D(real): 0.898 | D(fake): 0.027
# Epoch 346 | D loss: 43.866 | G loss: 554.011 | D(real): 0.888 | D(fake): 0.000
# Epoch 347 | D loss: 39.170 | G loss: 571.659 | D(real): 0.863 | D(fake): 0.000
# Epoch 348 | D loss: 37.326 | G loss: 216.638 | D(real): 0.922 | D(fake): 0.000
# Epoch 349 | D loss: 42.702 | G loss: 216.614 | D(real): 0.914 | D(fake): 0.008
# Epoch 350 | D loss: 30.720 | G loss: 173.526 | D(real): 0.870 | D(fake): 0.000
# Epoch 351 | D loss: 68.818 | G loss: 250.651 | D(real): 0.779 | D(fake): 0.145
# Epoch 352 | D loss: 150.030 | G loss: 845.958 | D(real): 0.696 | D(fake): 0.124
# Epoch 353 | D loss: 198.314 | G loss: 777.469 | D(real): 0.847 | D(fake): 0.125
# Epoch 354 | D loss: 149.496 | G loss: 716.932 | D(real): 0.844 | D(fake): 0.046
# Epoch 355 | D loss: 76.608 | G loss: 485.320 | D(real): 0.850 | D(fake): 0.056
# Epoch 356 | D loss: 57.117 | G loss: 362.100 | D(real): 0.876 | D(fake): 0.000
# Epoch 357 | D loss: 45.301 | G loss: 262.150 | D(real): 0.831 | D(fake): 0.033
# Epoch 358 | D loss: 51.274 | G loss: 234.131 | D(real): 0.871 | D(fake): 0.104
# Epoch 359 | D loss: 52.923 | G loss: 318.793 | D(real): 0.852 | D(fake): 0.031
# Epoch 360 | D loss: 54.880 | G loss: 371.780 | D(real): 0.817 | D(fake): 0.073
# Epoch 361 | D loss: 66.931 | G loss: 407.574 | D(real): 0.770 | D(fake): 0.035
# Epoch 362 | D loss: 56.642 | G loss: 275.319 | D(real): 0.855 | D(fake): 0.065
# Epoch 363 | D loss: 42.398 | G loss: 278.478 | D(real): 0.856 | D(fake): 0.020
# Epoch 364 | D loss: 69.154 | G loss: 400.841 | D(real): 0.837 | D(fake): 0.035
# Epoch 365 | D loss: 95.164 | G loss: 493.857 | D(real): 0.791 | D(fake): 0.067
# Epoch 366 | D loss: 84.987 | G loss: 607.829 | D(real): 0.902 | D(fake): 0.008
# Epoch 367 | D loss: 73.525 | G loss: 310.981 | D(real): 0.900 | D(fake): 0.012
# Epoch 368 | D loss: 45.404 | G loss: 412.299 | D(real): 0.857 | D(fake): 0.000
# Epoch 369 | D loss: 33.255 | G loss: 246.311 | D(real): 0.890 | D(fake): 0.000
# Epoch 370 | D loss: 30.385 | G loss: 117.498 | D(real): 0.910 | D(fake): 0.008
# Epoch 371 | D loss: 26.538 | G loss: 165.195 | D(real): 0.882 | D(fake): 0.000
# Epoch 372 | D loss: 29.406 | G loss: 144.006 | D(real): 0.859 | D(fake): 0.016
# Epoch 373 | D loss: 37.164 | G loss: 216.699 | D(real): 0.867 | D(fake): 0.000
# Epoch 374 | D loss: 166.272 | G loss: 236.906 | D(real): 0.687 | D(fake): 0.239
# Epoch 375 | D loss: 185.084 | G loss: 904.906 | D(real): 0.788 | D(fake): 0.000
# Epoch 376 | D loss: 232.503 | G loss: 878.942 | D(real): 0.805 | D(fake): 0.129
# Epoch 377 | D loss: 156.929 | G loss: 698.324 | D(real): 0.883 | D(fake): 0.125
# Epoch 378 | D loss: 255.753 | G loss: 730.769 | D(real): 0.701 | D(fake): 0.166
# Epoch 379 | D loss: 194.821 | G loss: 786.738 | D(real): 0.770 | D(fake): 0.125
# Epoch 380 | D loss: 136.695 | G loss: 858.644 | D(real): 0.754 | D(fake): 0.052
# Epoch 381 | D loss: 117.636 | G loss: 710.750 | D(real): 0.837 | D(fake): 0.000
# Epoch 382 | D loss: 67.918 | G loss: 221.084 | D(real): 0.879 | D(fake): 0.064
# Epoch 383 | D loss: 60.308 | G loss: 500.673 | D(real): 0.868 | D(fake): 0.008
# Epoch 384 | D loss: 51.261 | G loss: 352.908 | D(real): 0.894 | D(fake): 0.000
# Epoch 385 | D loss: 57.061 | G loss: 250.873 | D(real): 0.738 | D(fake): 0.085
# Epoch 386 | D loss: 128.197 | G loss: 852.606 | D(real): 0.777 | D(fake): 0.124
# Epoch 387 | D loss: 126.414 | G loss: 413.448 | D(real): 0.945 | D(fake): 0.043
# Epoch 388 | D loss: 109.920 | G loss: 534.232 | D(real): 0.832 | D(fake): 0.043
# Epoch 389 | D loss: 58.180 | G loss: 307.947 | D(real): 0.871 | D(fake): 0.021
# Epoch 390 | D loss: 42.995 | G loss: 333.720 | D(real): 0.871 | D(fake): 0.008
# Epoch 391 | D loss: 35.992 | G loss: 270.438 | D(real): 0.863 | D(fake): 0.004
# Epoch 392 | D loss: 27.983 | G loss: 190.277 | D(real): 0.882 | D(fake): 0.000
# Epoch 393 | D loss: 25.411 | G loss: 177.665 | D(real): 0.893 | D(fake): 0.000
# Epoch 394 | D loss: 88.381 | G loss: 375.944 | D(real): 0.758 | D(fake): 0.198
# Epoch 395 | D loss: 145.333 | G loss: 740.600 | D(real): 0.801 | D(fake): 0.020
# Epoch 396 | D loss: 103.347 | G loss: 494.946 | D(real): 0.891 | D(fake): 0.000
# Epoch 397 | D loss: 52.051 | G loss: 250.113 | D(real): 0.803 | D(fake): 0.067
# Epoch 398 | D loss: 56.806 | G loss: 271.489 | D(real): 0.855 | D(fake): 0.000
# Epoch 399 | D loss: 67.055 | G loss: 318.629 | D(real): 0.875 | D(fake): 0.004
# Epoch 400 | D loss: 147.730 | G loss: 358.577 | D(real): 0.731 | D(fake): 0.250
# Epoch 401 | D loss: 93.011 | G loss: 594.241 | D(real): 0.789 | D(fake): 0.023
# Epoch 402 | D loss: 71.009 | G loss: 441.373 | D(real): 0.872 | D(fake): 0.004
# Epoch 403 | D loss: 38.600 | G loss: 192.367 | D(real): 0.912 | D(fake): 0.010
# Epoch 404 | D loss: 33.373 | G loss: 214.293 | D(real): 0.904 | D(fake): 0.000
# Epoch 405 | D loss: 36.955 | G loss: 231.056 | D(real): 0.897 | D(fake): 0.008
# Epoch 406 | D loss: 38.076 | G loss: 168.988 | D(real): 0.843 | D(fake): 0.004
# Epoch 407 | D loss: 27.415 | G loss: 86.550 | D(real): 0.887 | D(fake): 0.051
# Epoch 408 | D loss: 66.407 | G loss: 256.034 | D(real): 0.789 | D(fake): 0.021
# Epoch 409 | D loss: 64.322 | G loss: 376.397 | D(real): 0.887 | D(fake): 0.000
# Epoch 410 | D loss: 84.619 | G loss: 356.058 | D(real): 0.789 | D(fake): 0.100
# Epoch 411 | D loss: 104.601 | G loss: 459.991 | D(real): 0.785 | D(fake): 0.121
# Epoch 412 | D loss: 90.525 | G loss: 435.002 | D(real): 0.899 | D(fake): 0.000
# Epoch 413 | D loss: 53.248 | G loss: 439.640 | D(real): 0.887 | D(fake): 0.004
# Epoch 414 | D loss: 54.659 | G loss: 357.083 | D(real): 0.795 | D(fake): 0.154
# Epoch 415 | D loss: 151.571 | G loss: 675.379 | D(real): 0.687 | D(fake): 0.152
# Epoch 416 | D loss: 151.789 | G loss: 586.508 | D(real): 0.816 | D(fake): 0.117
# Epoch 417 | D loss: 121.514 | G loss: 744.109 | D(real): 0.809 | D(fake): 0.004
# Epoch 418 | D loss: 80.976 | G loss: 544.295 | D(real): 0.856 | D(fake): 0.019
# Epoch 419 | D loss: 51.966 | G loss: 224.512 | D(real): 0.875 | D(fake): 0.030
# Epoch 420 | D loss: 41.322 | G loss: 287.010 | D(real): 0.906 | D(fake): 0.008
# Epoch 421 | D loss: 39.358 | G loss: 279.895 | D(real): 0.890 | D(fake): 0.004
# Epoch 422 | D loss: 33.457 | G loss: 205.718 | D(real): 0.881 | D(fake): 0.004
# Epoch 423 | D loss: 32.568 | G loss: 163.486 | D(real): 0.867 | D(fake): 0.021
# Epoch 424 | D loss: 29.664 | G loss: 150.245 | D(real): 0.891 | D(fake): 0.016
# Epoch 425 | D loss: 30.827 | G loss: 145.694 | D(real): 0.852 | D(fake): 0.048
# Epoch 426 | D loss: 40.069 | G loss: 247.398 | D(real): 0.867 | D(fake): 0.000
# Epoch 427 | D loss: 36.954 | G loss: 186.269 | D(real): 0.847 | D(fake): 0.061
# Epoch 428 | D loss: 41.849 | G loss: 255.982 | D(real): 0.820 | D(fake): 0.020
# Epoch 429 | D loss: 51.183 | G loss: 214.411 | D(real): 0.752 | D(fake): 0.047
# Epoch 430 | D loss: 121.207 | G loss: 529.793 | D(real): 0.798 | D(fake): 0.226
# Epoch 431 | D loss: 104.713 | G loss: 617.584 | D(real): 0.794 | D(fake): 0.023
# Epoch 432 | D loss: 80.801 | G loss: 495.803 | D(real): 0.815 | D(fake): 0.036
# Epoch 433 | D loss: 74.799 | G loss: 378.373 | D(real): 0.828 | D(fake): 0.093
# Epoch 434 | D loss: 52.066 | G loss: 312.599 | D(real): 0.875 | D(fake): 0.012
# Epoch 435 | D loss: 67.040 | G loss: 317.763 | D(real): 0.793 | D(fake): 0.043
# Epoch 436 | D loss: 55.145 | G loss: 292.001 | D(real): 0.845 | D(fake): 0.008
# Epoch 437 | D loss: 40.607 | G loss: 228.953 | D(real): 0.857 | D(fake): 0.050
# Epoch 438 | D loss: 35.253 | G loss: 238.019 | D(real): 0.846 | D(fake): 0.014
# Epoch 439 | D loss: 27.775 | G loss: 190.007 | D(real): 0.843 | D(fake): 0.024
# Epoch 440 | D loss: 32.730 | G loss: 265.571 | D(real): 0.902 | D(fake): 0.066
# Epoch 441 | D loss: 185.386 | G loss: 817.516 | D(real): 0.641 | D(fake): 0.125
# Epoch 442 | D loss: 166.623 | G loss: 978.611 | D(real): 0.821 | D(fake): 0.125
# Epoch 443 | D loss: 154.368 | G loss: 760.401 | D(real): 0.867 | D(fake): 0.072
# Epoch 444 | D loss: 156.531 | G loss: 856.105 | D(real): 0.778 | D(fake): 0.125
# Epoch 445 | D loss: 115.030 | G loss: 705.539 | D(real): 0.801 | D(fake): 0.067
# Epoch 446 | D loss: 114.105 | G loss: 765.362 | D(real): 0.801 | D(fake): 0.000
# Epoch 447 | D loss: 84.827 | G loss: 407.171 | D(real): 0.876 | D(fake): 0.012
# Epoch 448 | D loss: 98.828 | G loss: 525.360 | D(real): 0.762 | D(fake): 0.129
# Epoch 449 | D loss: 111.599 | G loss: 412.446 | D(real): 0.957 | D(fake): 0.016
# Epoch 450 | D loss: 70.779 | G loss: 609.127 | D(real): 0.822 | D(fake): 0.125
# Epoch 451 | D loss: 102.008 | G loss: 416.220 | D(real): 0.786 | D(fake): 0.030
# Epoch 452 | D loss: 83.641 | G loss: 544.141 | D(real): 0.859 | D(fake): 0.000
# Epoch 453 | D loss: 106.600 | G loss: 326.694 | D(real): 0.696 | D(fake): 0.122
# Epoch 454 | D loss: 117.195 | G loss: 637.653 | D(real): 0.908 | D(fake): 0.086
# Epoch 455 | D loss: 131.641 | G loss: 463.315 | D(real): 0.883 | D(fake): 0.056
# Epoch 456 | D loss: 102.680 | G loss: 490.898 | D(real): 0.820 | D(fake): 0.081
# Epoch 457 | D loss: 63.023 | G loss: 339.755 | D(real): 0.781 | D(fake): 0.092
# Epoch 458 | D loss: 93.141 | G loss: 384.794 | D(real): 0.813 | D(fake): 0.058
# Epoch 459 | D loss: 86.455 | G loss: 389.164 | D(real): 0.856 | D(fake): 0.016
# Epoch 460 | D loss: 59.829 | G loss: 305.847 | D(real): 0.874 | D(fake): 0.125
# Epoch 461 | D loss: 129.651 | G loss: 422.172 | D(real): 0.676 | D(fake): 0.125
# Epoch 462 | D loss: 113.995 | G loss: 531.656 | D(real): 0.773 | D(fake): 0.125
# Epoch 463 | D loss: 111.182 | G loss: 519.362 | D(real): 0.731 | D(fake): 0.125
# Epoch 464 | D loss: 120.807 | G loss: 509.892 | D(real): 0.738 | D(fake): 0.125
# Epoch 465 | D loss: 129.900 | G loss: 487.771 | D(real): 0.784 | D(fake): 0.133
# Epoch 466 | D loss: 95.610 | G loss: 480.113 | D(real): 0.781 | D(fake): 0.124
# Epoch 467 | D loss: 82.585 | G loss: 457.158 | D(real): 0.804 | D(fake): 0.134
# Epoch 468 | D loss: 63.163 | G loss: 468.735 | D(real): 0.863 | D(fake): 0.000
# Epoch 469 | D loss: 50.309 | G loss: 221.751 | D(real): 0.887 | D(fake): 0.004
# Epoch 470 | D loss: 47.290 | G loss: 310.580 | D(real): 0.879 | D(fake): 0.000
# Epoch 471 | D loss: 43.789 | G loss: 236.927 | D(real): 0.903 | D(fake): 0.000
# Epoch 472 | D loss: 33.793 | G loss: 150.131 | D(real): 0.887 | D(fake): 0.022
# Epoch 473 | D loss: 30.001 | G loss: 115.391 | D(real): 0.864 | D(fake): 0.035
# Epoch 474 | D loss: 54.831 | G loss: 187.676 | D(real): 0.774 | D(fake): 0.184
# Epoch 475 | D loss: 119.117 | G loss: 487.905 | D(real): 0.668 | D(fake): 0.125
# Epoch 476 | D loss: 82.726 | G loss: 344.762 | D(real): 0.812 | D(fake): 0.086
# Epoch 477 | D loss: 57.505 | G loss: 282.323 | D(real): 0.859 | D(fake): 0.075
# Epoch 478 | D loss: 118.669 | G loss: 425.031 | D(real): 0.674 | D(fake): 0.101
# Epoch 479 | D loss: 113.800 | G loss: 404.068 | D(real): 0.825 | D(fake): 0.125
# Epoch 480 | D loss: 68.216 | G loss: 362.814 | D(real): 0.859 | D(fake): 0.071
# Epoch 481 | D loss: 47.013 | G loss: 283.063 | D(real): 0.847 | D(fake): 0.012
# Epoch 482 | D loss: 59.522 | G loss: 219.967 | D(real): 0.898 | D(fake): 0.125
# Epoch 483 | D loss: 178.744 | G loss: 412.816 | D(real): 0.625 | D(fake): 0.129
# Epoch 484 | D loss: 133.349 | G loss: 395.307 | D(real): 0.812 | D(fake): 0.218
# Epoch 485 | D loss: 136.893 | G loss: 647.922 | D(real): 0.770 | D(fake): 0.086
# Epoch 486 | D loss: 68.038 | G loss: 495.939 | D(real): 0.838 | D(fake): 0.008
# Epoch 487 | D loss: 47.752 | G loss: 283.880 | D(real): 0.890 | D(fake): 0.008
# Epoch 488 | D loss: 81.506 | G loss: 295.926 | D(real): 0.734 | D(fake): 0.135
# Epoch 489 | D loss: 160.060 | G loss: 259.971 | D(real): 0.715 | D(fake): 0.152
# Epoch 490 | D loss: 165.575 | G loss: 525.711 | D(real): 0.762 | D(fake): 0.232
# Epoch 491 | D loss: 131.407 | G loss: 739.232 | D(real): 0.796 | D(fake): 0.054
# Epoch 492 | D loss: 107.647 | G loss: 732.670 | D(real): 0.820 | D(fake): 0.117
# Epoch 493 | D loss: 159.979 | G loss: 490.230 | D(real): 0.687 | D(fake): 0.129
# Epoch 494 | D loss: 146.929 | G loss: 321.772 | D(real): 0.730 | D(fake): 0.129
# Epoch 495 | D loss: 59.515 | G loss: 271.870 | D(real): 0.875 | D(fake): 0.038
# Epoch 496 | D loss: 56.820 | G loss: 324.383 | D(real): 0.889 | D(fake): 0.000
# Epoch 497 | D loss: 43.540 | G loss: 317.225 | D(real): 0.887 | D(fake): 0.000
# Epoch 498 | D loss: 136.539 | G loss: 363.147 | D(real): 0.687 | D(fake): 0.247
# Epoch 499 | D loss: 126.412 | G loss: 1040.685 | D(real): 0.848 | D(fake): 0.000
# Epoch 500 | D loss: 106.162 | G loss: 713.562 | D(real): 0.888 | D(fake): 0.043
# Epoch 501 | D loss: 293.225 | G loss: 425.579 | D(real): 0.615 | D(fake): 0.345
# Epoch 502 | D loss: 464.543 | G loss: 907.802 | D(real): 0.660 | D(fake): 0.132
# Epoch 503 | D loss: 169.233 | G loss: 812.531 | D(real): 0.852 | D(fake): 0.000
# Epoch 504 | D loss: 249.633 | G loss: 871.018 | D(real): 0.691 | D(fake): 0.102
# Epoch 505 | D loss: 683.618 | G loss: 842.520 | D(real): 0.598 | D(fake): 0.458
# Epoch 506 | D loss: 423.496 | G loss: 632.833 | D(real): 0.766 | D(fake): 0.129
# Epoch 507 | D loss: 229.039 | G loss: 1129.253 | D(real): 0.738 | D(fake): 0.109
# Epoch 508 | D loss: 309.630 | G loss: 1371.799 | D(real): 0.699 | D(fake): 0.105
# Epoch 509 | D loss: 233.290 | G loss: 999.416 | D(real): 0.816 | D(fake): 0.236
# Epoch 510 | D loss: 310.749 | G loss: 568.952 | D(real): 0.703 | D(fake): 0.114
# Epoch 511 | D loss: 230.158 | G loss: 244.590 | D(real): 0.703 | D(fake): 0.250
# Epoch 512 | D loss: 127.230 | G loss: 374.172 | D(real): 0.840 | D(fake): 0.098
# Epoch 513 | D loss: 63.025 | G loss: 1040.031 | D(real): 0.874 | D(fake): 0.000
# Epoch 514 | D loss: 65.674 | G loss: 781.396 | D(real): 0.863 | D(fake): 0.000
# Epoch 515 | D loss: 66.341 | G loss: 481.032 | D(real): 0.890 | D(fake): 0.000
# Epoch 516 | D loss: 52.520 | G loss: 244.395 | D(real): 0.918 | D(fake): 0.012
# Epoch 517 | D loss: 61.541 | G loss: 392.315 | D(real): 0.820 | D(fake): 0.016
# Epoch 518 | D loss: 63.208 | G loss: 395.097 | D(real): 0.906 | D(fake): 0.000
# Epoch 519 | D loss: 45.131 | G loss: 291.959 | D(real): 0.893 | D(fake): 0.000
# Epoch 520 | D loss: 28.252 | G loss: 306.727 | D(real): 0.902 | D(fake): 0.000
# Epoch 521 | D loss: 28.062 | G loss: 237.513 | D(real): 0.879 | D(fake): 0.000
# Epoch 522 | D loss: 51.154 | G loss: 257.809 | D(real): 0.818 | D(fake): 0.114
# Epoch 523 | D loss: 95.736 | G loss: 313.856 | D(real): 0.767 | D(fake): 0.081
# Epoch 524 | D loss: 65.525 | G loss: 289.309 | D(real): 0.895 | D(fake): 0.043
# Epoch 525 | D loss: 54.150 | G loss: 258.534 | D(real): 0.852 | D(fake): 0.037
# Epoch 526 | D loss: 41.697 | G loss: 245.049 | D(real): 0.873 | D(fake): 0.000
# Epoch 527 | D loss: 32.622 | G loss: 138.863 | D(real): 0.874 | D(fake): 0.037
# Epoch 528 | D loss: 33.469 | G loss: 196.988 | D(real): 0.885 | D(fake): 0.044
# Epoch 529 | D loss: 33.664 | G loss: 188.302 | D(real): 0.838 | D(fake): 0.012
# Epoch 530 | D loss: 23.074 | G loss: 120.439 | D(real): 0.855 | D(fake): 0.035
# Epoch 531 | D loss: 24.358 | G loss: 119.791 | D(real): 0.855 | D(fake): 0.035
# Epoch 532 | D loss: 59.926 | G loss: 128.056 | D(real): 0.783 | D(fake): 0.193
# Epoch 533 | D loss: 48.275 | G loss: 210.559 | D(real): 0.861 | D(fake): 0.023
# Epoch 534 | D loss: 44.927 | G loss: 183.367 | D(real): 0.790 | D(fake): 0.023
# Epoch 535 | D loss: 59.913 | G loss: 247.013 | D(real): 0.856 | D(fake): 0.109
# Epoch 536 | D loss: 39.977 | G loss: 289.606 | D(real): 0.881 | D(fake): 0.000
# Epoch 537 | D loss: 25.018 | G loss: 113.880 | D(real): 0.894 | D(fake): 0.012
# Epoch 538 | D loss: 27.862 | G loss: 160.613 | D(real): 0.838 | D(fake): 0.032
# Epoch 539 | D loss: 27.074 | G loss: 95.393 | D(real): 0.912 | D(fake): 0.086
# Epoch 540 | D loss: 31.833 | G loss: 175.514 | D(real): 0.785 | D(fake): 0.061
# Epoch 541 | D loss: 29.575 | G loss: 171.841 | D(real): 0.905 | D(fake): 0.024
# Epoch 542 | D loss: 33.752 | G loss: 200.552 | D(real): 0.785 | D(fake): 0.057
# Epoch 543 | D loss: 56.428 | G loss: 187.296 | D(real): 0.863 | D(fake): 0.135
# Epoch 544 | D loss: 34.177 | G loss: 256.931 | D(real): 0.875 | D(fake): 0.008
# Epoch 545 | D loss: 36.619 | G loss: 162.009 | D(real): 0.833 | D(fake): 0.058
# Epoch 546 | D loss: 25.849 | G loss: 195.412 | D(real): 0.908 | D(fake): 0.004
# Epoch 547 | D loss: 21.060 | G loss: 159.211 | D(real): 0.905 | D(fake): 0.000
# Epoch 548 | D loss: 36.687 | G loss: 118.070 | D(real): 0.780 | D(fake): 0.132
# Epoch 549 | D loss: 27.276 | G loss: 146.718 | D(real): 0.879 | D(fake): 0.015
# Epoch 550 | D loss: 20.685 | G loss: 94.348 | D(real): 0.862 | D(fake): 0.031
# Epoch 551 | D loss: 33.975 | G loss: 134.410 | D(real): 0.808 | D(fake): 0.060
# Epoch 552 | D loss: 45.866 | G loss: 207.273 | D(real): 0.726 | D(fake): 0.113
# Epoch 553 | D loss: 44.976 | G loss: 201.727 | D(real): 0.879 | D(fake): 0.057
# Epoch 554 | D loss: 34.831 | G loss: 190.417 | D(real): 0.894 | D(fake): 0.004
# Epoch 555 | D loss: 22.829 | G loss: 124.441 | D(real): 0.860 | D(fake): 0.031
# Epoch 556 | D loss: 66.603 | G loss: 202.284 | D(real): 0.691 | D(fake): 0.258
# Epoch 557 | D loss: 98.047 | G loss: 380.081 | D(real): 0.793 | D(fake): 0.129
# Epoch 558 | D loss: 96.870 | G loss: 425.875 | D(real): 0.688 | D(fake): 0.116
# Epoch 559 | D loss: 78.388 | G loss: 332.863 | D(real): 0.815 | D(fake): 0.092
# Epoch 560 | D loss: 58.940 | G loss: 251.444 | D(real): 0.870 | D(fake): 0.020
# Epoch 561 | D loss: 42.307 | G loss: 172.522 | D(real): 0.810 | D(fake): 0.055
# Epoch 562 | D loss: 40.482 | G loss: 180.349 | D(real): 0.892 | D(fake): 0.014
# Epoch 563 | D loss: 41.470 | G loss: 259.477 | D(real): 0.821 | D(fake): 0.035
# Epoch 564 | D loss: 40.191 | G loss: 177.791 | D(real): 0.889 | D(fake): 0.099
# Epoch 565 | D loss: 59.544 | G loss: 276.168 | D(real): 0.789 | D(fake): 0.020
# Epoch 566 | D loss: 59.995 | G loss: 208.789 | D(real): 0.812 | D(fake): 0.138
# Epoch 567 | D loss: 99.253 | G loss: 422.447 | D(real): 0.665 | D(fake): 0.081
# Epoch 568 | D loss: 109.362 | G loss: 447.036 | D(real): 0.750 | D(fake): 0.246
# Epoch 569 | D loss: 107.543 | G loss: 384.826 | D(real): 0.812 | D(fake): 0.081
# Epoch 570 | D loss: 120.985 | G loss: 349.665 | D(real): 0.688 | D(fake): 0.117
# Epoch 571 | D loss: 124.351 | G loss: 428.223 | D(real): 0.771 | D(fake): 0.225
# Epoch 572 | D loss: 134.267 | G loss: 568.397 | D(real): 0.797 | D(fake): 0.059
# Epoch 573 | D loss: 72.151 | G loss: 611.516 | D(real): 0.876 | D(fake): 0.016
# Epoch 574 | D loss: 65.916 | G loss: 229.302 | D(real): 0.743 | D(fake): 0.183
# Epoch 575 | D loss: 126.088 | G loss: 317.831 | D(real): 0.691 | D(fake): 0.081
# Epoch 576 | D loss: 101.278 | G loss: 313.953 | D(real): 0.843 | D(fake): 0.090
# Epoch 577 | D loss: 70.974 | G loss: 439.333 | D(real): 0.897 | D(fake): 0.004
# Epoch 578 | D loss: 64.100 | G loss: 301.458 | D(real): 0.703 | D(fake): 0.075
# Epoch 579 | D loss: 125.176 | G loss: 545.660 | D(real): 0.820 | D(fake): 0.084
# Epoch 580 | D loss: 85.425 | G loss: 272.182 | D(real): 0.809 | D(fake): 0.028
# Epoch 581 | D loss: 71.352 | G loss: 154.182 | D(real): 0.717 | D(fake): 0.136
# Epoch 582 | D loss: 65.922 | G loss: 424.790 | D(real): 0.837 | D(fake): 0.031
# Epoch 583 | D loss: 37.013 | G loss: 388.969 | D(real): 0.848 | D(fake): 0.039
# Epoch 584 | D loss: 39.120 | G loss: 372.130 | D(real): 0.902 | D(fake): 0.040
# Epoch 585 | D loss: 30.558 | G loss: 311.542 | D(real): 0.828 | D(fake): 0.027
# Epoch 586 | D loss: 47.186 | G loss: 213.713 | D(real): 0.809 | D(fake): 0.091
# Epoch 587 | D loss: 135.053 | G loss: 385.643 | D(real): 0.608 | D(fake): 0.147
# Epoch 588 | D loss: 95.624 | G loss: 254.879 | D(real): 0.764 | D(fake): 0.186
# Epoch 589 | D loss: 71.464 | G loss: 419.796 | D(real): 0.800 | D(fake): 0.032
# Epoch 590 | D loss: 55.487 | G loss: 293.187 | D(real): 0.808 | D(fake): 0.047
# Epoch 591 | D loss: 41.918 | G loss: 282.098 | D(real): 0.803 | D(fake): 0.051
# Epoch 592 | D loss: 77.612 | G loss: 278.802 | D(real): 0.754 | D(fake): 0.102
# Epoch 593 | D loss: 54.435 | G loss: 217.809 | D(real): 0.884 | D(fake): 0.008
# Epoch 594 | D loss: 196.791 | G loss: 439.839 | D(real): 0.664 | D(fake): 0.233
# Epoch 595 | D loss: 163.550 | G loss: 767.810 | D(real): 0.805 | D(fake): 0.043
# Epoch 596 | D loss: 86.917 | G loss: 790.213 | D(real): 0.869 | D(fake): 0.000
# Epoch 597 | D loss: 137.181 | G loss: 540.045 | D(real): 0.741 | D(fake): 0.168
# Epoch 598 | D loss: 88.280 | G loss: 457.066 | D(real): 0.812 | D(fake): 0.031
# Epoch 599 | D loss: 141.536 | G loss: 292.690 | D(real): 0.674 | D(fake): 0.238
# Epoch 600 | D loss: 175.088 | G loss: 418.668 | D(real): 0.633 | D(fake): 0.254
# Epoch 601 | D loss: 328.613 | G loss: 670.335 | D(real): 0.714 | D(fake): 0.209
# ...
# Epoch 1799 | D loss: 30.684 | G loss: 231.679 | D(real): 0.879 | D(fake): 0.027
# Epoch 1800 | D loss: 21.134 | G loss: 224.341 | D(real): 0.887 | D(fake): 0.027
# Epoch 1801 | D loss: 16.826 | G loss: 201.907 | D(real): 0.837 | D(fake): 0.008
# Epoch 1802 | D loss: 12.746 | G loss: 179.874 | D(real): 0.907 | D(fake): 0.008
# Epoch 1803 | D loss: 17.900 | G loss: 138.912 | D(real): 0.822 | D(fake): 0.032
# Epoch 1804 | D loss: 31.928 | G loss: 122.595 | D(real): 0.867 | D(fake): 0.084
# Epoch 1805 | D loss: 35.447 | G loss: 128.522 | D(real): 0.847 | D(fake): 0.078
# Epoch 1806 | D loss: 32.130 | G loss: 163.481 | D(real): 0.844 | D(fake): 0.035
# Epoch 1807 | D loss: 17.911 | G loss: 180.134 | D(real): 0.875 | D(fake): 0.016
# Epoch 1808 | D loss: 15.660 | G loss: 172.990 | D(real): 0.863 | D(fake): 0.004
# Epoch 1809 | D loss: 13.639 | G loss: 143.076 | D(real): 0.879 | D(fake): 0.004
# Epoch 1810 | D loss: 9.904 | G loss: 122.233 | D(real): 0.888 | D(fake): 0.016
# Epoch 1811 | D loss: 10.623 | G loss: 116.570 | D(real): 0.882 | D(fake): 0.012
# Epoch 1812 | D loss: 8.540 | G loss: 103.261 | D(real): 0.874 | D(fake): 0.012
# Epoch 1813 | D loss: 7.975 | G loss: 93.121 | D(real): 0.895 | D(fake): 0.012
# Epoch 1814 | D loss: 10.295 | G loss: 88.656 | D(real): 0.869 | D(fake): 0.042
# Epoch 1815 | D loss: 11.349 | G loss: 78.958 | D(real): 0.867 | D(fake): 0.031
# Epoch 1816 | D loss: 8.802 | G loss: 90.599 | D(real): 0.872 | D(fake): 0.004
# Epoch 1817 | D loss: 8.186 | G loss: 89.632 | D(real): 0.860 | D(fake): 0.016
# Epoch 1818 | D loss: 10.264 | G loss: 77.016 | D(real): 0.862 | D(fake): 0.030
# Epoch 1819 | D loss: 10.779 | G loss: 71.389 | D(real): 0.874 | D(fake): 0.055
# Epoch 1820 | D loss: 8.835 | G loss: 89.794 | D(real): 0.888 | D(fake): 0.017
# Epoch 1821 | D loss: 9.354 | G loss: 78.504 | D(real): 0.861 | D(fake): 0.014
# Epoch 1822 | D loss: 8.872 | G loss: 70.998 | D(real): 0.868 | D(fake): 0.016
# Epoch 1823 | D loss: 8.348 | G loss: 68.511 | D(real): 0.854 | D(fake): 0.031
# Epoch 1824 | D loss: 7.626 | G loss: 61.982 | D(real): 0.886 | D(fake): 0.016
# Epoch 1825 | D loss: 6.533 | G loss: 60.775 | D(real): 0.872 | D(fake): 0.045
# Epoch 1826 | D loss: 10.217 | G loss: 66.975 | D(real): 0.888 | D(fake): 0.010
# Epoch 1827 | D loss: 9.256 | G loss: 63.357 | D(real): 0.886 | D(fake): 0.008
# Epoch 1828 | D loss: 27.382 | G loss: 62.536 | D(real): 0.760 | D(fake): 0.124
# Epoch 1829 | D loss: 20.990 | G loss: 101.350 | D(real): 0.848 | D(fake): 0.025
# Epoch 1830 | D loss: 14.208 | G loss: 110.229 | D(real): 0.892 | D(fake): 0.008
# Epoch 1831 | D loss: 10.561 | G loss: 89.425 | D(real): 0.861 | D(fake): 0.012
# Epoch 1832 | D loss: 10.753 | G loss: 78.367 | D(real): 0.858 | D(fake): 0.057
# Epoch 1833 | D loss: 8.135 | G loss: 77.373 | D(real): 0.897 | D(fake): 0.012
# Epoch 1834 | D loss: 7.347 | G loss: 66.977 | D(real): 0.858 | D(fake): 0.043
# Epoch 1835 | D loss: 7.855 | G loss: 73.897 | D(real): 0.867 | D(fake): 0.020
# Epoch 1836 | D loss: 8.075 | G loss: 65.929 | D(real): 0.873 | D(fake): 0.031
# Epoch 1837 | D loss: 8.152 | G loss: 67.737 | D(real): 0.893 | D(fake): 0.026
# Epoch 1838 | D loss: 7.173 | G loss: 65.562 | D(real): 0.872 | D(fake): 0.015
# Epoch 1839 | D loss: 4.874 | G loss: 62.408 | D(real): 0.896 | D(fake): 0.005
# Epoch 1840 | D loss: 4.246 | G loss: 52.092 | D(real): 0.865 | D(fake): 0.013
# Epoch 1841 | D loss: 9.681 | G loss: 54.996 | D(real): 0.819 | D(fake): 0.058
# Epoch 1842 | D loss: 6.559 | G loss: 57.055 | D(real): 0.860 | D(fake): 0.023
# Epoch 1843 | D loss: 8.051 | G loss: 54.967 | D(real): 0.846 | D(fake): 0.022
# Epoch 1844 | D loss: 6.273 | G loss: 48.640 | D(real): 0.882 | D(fake): 0.049
# Epoch 1845 | D loss: 8.646 | G loss: 51.876 | D(real): 0.840 | D(fake): 0.024
# Epoch 1846 | D loss: 10.995 | G loss: 54.868 | D(real): 0.898 | D(fake): 0.033
# Epoch 1847 | D loss: 8.420 | G loss: 47.404 | D(real): 0.854 | D(fake): 0.063
# Epoch 1848 | D loss: 7.673 | G loss: 52.937 | D(real): 0.818 | D(fake): 0.043
# Epoch 1849 | D loss: 17.758 | G loss: 70.065 | D(real): 0.849 | D(fake): 0.112
# Epoch 1850 | D loss: 9.637 | G loss: 92.605 | D(real): 0.856 | D(fake): 0.008
# Epoch 1851 | D loss: 14.712 | G loss: 69.398 | D(real): 0.819 | D(fake): 0.076
# Epoch 1852 | D loss: 16.153 | G loss: 79.290 | D(real): 0.876 | D(fake): 0.066
# Epoch 1853 | D loss: 14.027 | G loss: 75.872 | D(real): 0.864 | D(fake): 0.031
# Epoch 1854 | D loss: 9.644 | G loss: 76.982 | D(real): 0.823 | D(fake): 0.008
# Epoch 1855 | D loss: 7.679 | G loss: 65.798 | D(real): 0.905 | D(fake): 0.029
# Epoch 1856 | D loss: 6.102 | G loss: 57.787 | D(real): 0.877 | D(fake): 0.018
# Epoch 1857 | D loss: 6.697 | G loss: 51.260 | D(real): 0.847 | D(fake): 0.048
# Epoch 1858 | D loss: 5.365 | G loss: 42.924 | D(real): 0.887 | D(fake): 0.032
# Epoch 1859 | D loss: 7.230 | G loss: 54.290 | D(real): 0.836 | D(fake): 0.013
# Epoch 1860 | D loss: 8.311 | G loss: 52.775 | D(real): 0.847 | D(fake): 0.033
# Epoch 1861 | D loss: 7.061 | G loss: 40.338 | D(real): 0.869 | D(fake): 0.060
# Epoch 1862 | D loss: 8.124 | G loss: 40.586 | D(real): 0.861 | D(fake): 0.035
# Epoch 1863 | D loss: 8.989 | G loss: 54.743 | D(real): 0.872 | D(fake): 0.016
# Epoch 1864 | D loss: 9.170 | G loss: 51.608 | D(real): 0.792 | D(fake): 0.050
# Epoch 1865 | D loss: 14.189 | G loss: 71.917 | D(real): 0.821 | D(fake): 0.014
# Epoch 1866 | D loss: 16.326 | G loss: 54.020 | D(real): 0.885 | D(fake): 0.057
# Epoch 1867 | D loss: 9.802 | G loss: 77.347 | D(real): 0.854 | D(fake): 0.000
# Epoch 1868 | D loss: 17.899 | G loss: 53.769 | D(real): 0.821 | D(fake): 0.095
# Epoch 1869 | D loss: 13.989 | G loss: 70.807 | D(real): 0.853 | D(fake): 0.059
# Epoch 1870 | D loss: 15.460 | G loss: 68.048 | D(real): 0.866 | D(fake): 0.020
# Epoch 1871 | D loss: 12.757 | G loss: 88.862 | D(real): 0.850 | D(fake): 0.023
# Epoch 1872 | D loss: 8.696 | G loss: 51.907 | D(real): 0.863 | D(fake): 0.074
# Epoch 1873 | D loss: 9.845 | G loss: 75.125 | D(real): 0.879 | D(fake): 0.031
# Epoch 1874 | D loss: 12.184 | G loss: 42.274 | D(real): 0.823 | D(fake): 0.152
# Epoch 1875 | D loss: 11.205 | G loss: 62.701 | D(real): 0.858 | D(fake): 0.015
# Epoch 1876 | D loss: 7.509 | G loss: 61.136 | D(real): 0.814 | D(fake): 0.035
# Epoch 1877 | D loss: 10.563 | G loss: 63.261 | D(real): 0.858 | D(fake): 0.020
# Epoch 1878 | D loss: 7.075 | G loss: 62.883 | D(real): 0.883 | D(fake): 0.020
# Epoch 1879 | D loss: 14.193 | G loss: 59.638 | D(real): 0.802 | D(fake): 0.157
# Epoch 1880 | D loss: 17.368 | G loss: 95.577 | D(real): 0.828 | D(fake): 0.000
# Epoch 1881 | D loss: 13.302 | G loss: 53.992 | D(real): 0.813 | D(fake): 0.069
# Epoch 1882 | D loss: 8.344 | G loss: 89.744 | D(real): 0.880 | D(fake): 0.015
# Epoch 1883 | D loss: 8.931 | G loss: 75.526 | D(real): 0.888 | D(fake): 0.004
# Epoch 1884 | D loss: 10.901 | G loss: 45.077 | D(real): 0.793 | D(fake): 0.136
# Epoch 1885 | D loss: 16.947 | G loss: 83.161 | D(real): 0.861 | D(fake): 0.021
# Epoch 1886 | D loss: 13.628 | G loss: 95.867 | D(real): 0.864 | D(fake): 0.043
# Epoch 1887 | D loss: 15.201 | G loss: 91.916 | D(real): 0.793 | D(fake): 0.032
# Epoch 1888 | D loss: 12.497 | G loss: 81.300 | D(real): 0.877 | D(fake): 0.043
# Epoch 1889 | D loss: 13.078 | G loss: 74.694 | D(real): 0.871 | D(fake): 0.067
# Epoch 1890 | D loss: 10.867 | G loss: 91.044 | D(real): 0.828 | D(fake): 0.006
# Epoch 1891 | D loss: 10.118 | G loss: 63.331 | D(real): 0.868 | D(fake): 0.034
# Epoch 1892 | D loss: 8.399 | G loss: 56.726 | D(real): 0.860 | D(fake): 0.030
# Epoch 1893 | D loss: 12.880 | G loss: 77.615 | D(real): 0.837 | D(fake): 0.133
# Epoch 1894 | D loss: 14.945 | G loss: 97.570 | D(real): 0.784 | D(fake): 0.028
# Epoch 1895 | D loss: 12.553 | G loss: 60.352 | D(real): 0.884 | D(fake): 0.025
# Epoch 1896 | D loss: 11.793 | G loss: 72.044 | D(real): 0.829 | D(fake): 0.039
# Epoch 1897 | D loss: 14.066 | G loss: 79.442 | D(real): 0.869 | D(fake): 0.052
# Epoch 1898 | D loss: 10.754 | G loss: 81.970 | D(real): 0.853 | D(fake): 0.017
# Epoch 1899 | D loss: 10.963 | G loss: 64.159 | D(real): 0.814 | D(fake): 0.037
# Epoch 1900 | D loss: 16.092 | G loss: 92.227 | D(real): 0.883 | D(fake): 0.016
# Epoch 1901 | D loss: 13.731 | G loss: 66.954 | D(real): 0.844 | D(fake): 0.054
# Epoch 1902 | D loss: 11.245 | G loss: 65.665 | D(real): 0.825 | D(fake): 0.037
# Epoch 1903 | D loss: 8.410 | G loss: 71.780 | D(real): 0.873 | D(fake): 0.013
# Epoch 1904 | D loss: 11.347 | G loss: 85.403 | D(real): 0.814 | D(fake): 0.026
# Epoch 1905 | D loss: 11.887 | G loss: 95.009 | D(real): 0.862 | D(fake): 0.027
# Epoch 1906 | D loss: 22.157 | G loss: 72.113 | D(real): 0.789 | D(fake): 0.101
# Epoch 1907 | D loss: 22.514 | G loss: 92.806 | D(real): 0.802 | D(fake): 0.056
# Epoch 1908 | D loss: 22.891 | G loss: 113.698 | D(real): 0.894 | D(fake): 0.022
# Epoch 1909 | D loss: 13.043 | G loss: 119.470 | D(real): 0.825 | D(fake): 0.008
# Epoch 1910 | D loss: 25.710 | G loss: 110.476 | D(real): 0.737 | D(fake): 0.077
# Epoch 1911 | D loss: 25.788 | G loss: 118.509 | D(real): 0.883 | D(fake): 0.077
# Epoch 1912 | D loss: 19.448 | G loss: 127.380 | D(real): 0.863 | D(fake): 0.004
# Epoch 1913 | D loss: 13.723 | G loss: 89.514 | D(real): 0.859 | D(fake): 0.031
# Epoch 1914 | D loss: 16.157 | G loss: 111.177 | D(real): 0.787 | D(fake): 0.079
# Epoch 1915 | D loss: 14.910 | G loss: 143.847 | D(real): 0.905 | D(fake): 0.021
# Epoch 1916 | D loss: 27.756 | G loss: 116.172 | D(real): 0.797 | D(fake): 0.111
# Epoch 1917 | D loss: 32.585 | G loss: 189.505 | D(real): 0.788 | D(fake): 0.057
# Epoch 1918 | D loss: 26.877 | G loss: 132.884 | D(real): 0.816 | D(fake): 0.047
# Epoch 1919 | D loss: 27.665 | G loss: 113.958 | D(real): 0.874 | D(fake): 0.102
# Epoch 1920 | D loss: 23.444 | G loss: 129.957 | D(real): 0.837 | D(fake): 0.043
# Epoch 1921 | D loss: 15.427 | G loss: 108.018 | D(real): 0.856 | D(fake): 0.032
# Epoch 1922 | D loss: 11.902 | G loss: 115.559 | D(real): 0.878 | D(fake): 0.012
# Epoch 1923 | D loss: 8.854 | G loss: 95.722 | D(real): 0.865 | D(fake): 0.012
# Epoch 1924 | D loss: 10.348 | G loss: 80.386 | D(real): 0.866 | D(fake): 0.021
# Epoch 1925 | D loss: 12.145 | G loss: 87.246 | D(real): 0.838 | D(fake): 0.042
# Epoch 1926 | D loss: 13.286 | G loss: 80.467 | D(real): 0.859 | D(fake): 0.042
# Epoch 1927 | D loss: 16.120 | G loss: 88.467 | D(real): 0.820 | D(fake): 0.016
# Epoch 1928 | D loss: 13.000 | G loss: 73.004 | D(real): 0.839 | D(fake): 0.009
# Epoch 1929 | D loss: 13.016 | G loss: 69.017 | D(real): 0.830 | D(fake): 0.082
# Epoch 1930 | D loss: 12.047 | G loss: 73.968 | D(real): 0.845 | D(fake): 0.031
# Epoch 1931 | D loss: 10.587 | G loss: 74.527 | D(real): 0.852 | D(fake): 0.008
# Epoch 1932 | D loss: 8.154 | G loss: 49.530 | D(real): 0.877 | D(fake): 0.028
# Epoch 1933 | D loss: 7.311 | G loss: 52.931 | D(real): 0.901 | D(fake): 0.020
# Epoch 1934 | D loss: 6.662 | G loss: 51.611 | D(real): 0.844 | D(fake): 0.014
# Epoch 1935 | D loss: 5.652 | G loss: 46.636 | D(real): 0.888 | D(fake): 0.004
# Epoch 1936 | D loss: 7.361 | G loss: 48.729 | D(real): 0.839 | D(fake): 0.025
# Epoch 1937 | D loss: 6.918 | G loss: 43.810 | D(real): 0.871 | D(fake): 0.022
# Epoch 1938 | D loss: 7.839 | G loss: 36.209 | D(real): 0.816 | D(fake): 0.137
# Epoch 1939 | D loss: 15.510 | G loss: 81.408 | D(real): 0.759 | D(fake): 0.066
# Epoch 1940 | D loss: 10.758 | G loss: 76.760 | D(real): 0.844 | D(fake): 0.016
# Epoch 1941 | D loss: 7.900 | G loss: 56.233 | D(real): 0.864 | D(fake): 0.051
# Epoch 1942 | D loss: 8.087 | G loss: 46.606 | D(real): 0.869 | D(fake): 0.041
# Epoch 1943 | D loss: 9.733 | G loss: 50.730 | D(real): 0.885 | D(fake): 0.048
# Epoch 1944 | D loss: 14.724 | G loss: 60.693 | D(real): 0.746 | D(fake): 0.102
# Epoch 1945 | D loss: 12.396 | G loss: 64.581 | D(real): 0.883 | D(fake): 0.043
# Epoch 1946 | D loss: 12.486 | G loss: 62.735 | D(real): 0.810 | D(fake): 0.078
# Epoch 1947 | D loss: 13.847 | G loss: 44.822 | D(real): 0.800 | D(fake): 0.124
# Epoch 1948 | D loss: 10.102 | G loss: 59.853 | D(real): 0.837 | D(fake): 0.047
# Epoch 1949 | D loss: 8.051 | G loss: 48.321 | D(real): 0.859 | D(fake): 0.053
# Epoch 1950 | D loss: 15.188 | G loss: 47.647 | D(real): 0.757 | D(fake): 0.121
# Epoch 1951 | D loss: 13.882 | G loss: 63.311 | D(real): 0.853 | D(fake): 0.034
# Epoch 1952 | D loss: 16.133 | G loss: 65.108 | D(real): 0.780 | D(fake): 0.075
# Epoch 1953 | D loss: 17.176 | G loss: 59.733 | D(real): 0.845 | D(fake): 0.083
# Epoch 1954 | D loss: 11.604 | G loss: 61.976 | D(real): 0.808 | D(fake): 0.023
# Epoch 1955 | D loss: 8.634 | G loss: 44.884 | D(real): 0.832 | D(fake): 0.068
# Epoch 1956 | D loss: 9.158 | G loss: 42.753 | D(real): 0.885 | D(fake): 0.027
# Epoch 1957 | D loss: 5.932 | G loss: 43.046 | D(real): 0.854 | D(fake): 0.033
# Epoch 1958 | D loss: 7.215 | G loss: 40.441 | D(real): 0.830 | D(fake): 0.084
# Epoch 1959 | D loss: 6.740 | G loss: 36.552 | D(real): 0.843 | D(fake): 0.025
# Epoch 1960 | D loss: 8.558 | G loss: 29.820 | D(real): 0.806 | D(fake): 0.158
# Epoch 1961 | D loss: 10.135 | G loss: 34.357 | D(real): 0.812 | D(fake): 0.141
# Epoch 1962 | D loss: 22.663 | G loss: 83.126 | D(real): 0.723 | D(fake): 0.078
# Epoch 1963 | D loss: 13.429 | G loss: 67.732 | D(real): 0.881 | D(fake): 0.051
# Epoch 1964 | D loss: 10.971 | G loss: 50.154 | D(real): 0.827 | D(fake): 0.055
# Epoch 1965 | D loss: 10.248 | G loss: 66.693 | D(real): 0.841 | D(fake): 0.016
# Epoch 1966 | D loss: 8.679 | G loss: 53.606 | D(real): 0.881 | D(fake): 0.027
# Epoch 1967 | D loss: 9.497 | G loss: 51.282 | D(real): 0.849 | D(fake): 0.042
# Epoch 1968 | D loss: 8.846 | G loss: 48.558 | D(real): 0.845 | D(fake): 0.062
# Epoch 1969 | D loss: 18.138 | G loss: 53.228 | D(real): 0.723 | D(fake): 0.153
# Epoch 1970 | D loss: 9.199 | G loss: 47.331 | D(real): 0.850 | D(fake): 0.057
# Epoch 1971 | D loss: 9.675 | G loss: 55.409 | D(real): 0.855 | D(fake): 0.033
# Epoch 1972 | D loss: 21.608 | G loss: 65.555 | D(real): 0.745 | D(fake): 0.171
# Epoch 1973 | D loss: 18.294 | G loss: 82.708 | D(real): 0.767 | D(fake): 0.053
# Epoch 1974 | D loss: 20.933 | G loss: 75.482 | D(real): 0.811 | D(fake): 0.090
# Epoch 1975 | D loss: 20.143 | G loss: 83.946 | D(real): 0.768 | D(fake): 0.082
# Epoch 1976 | D loss: 16.916 | G loss: 67.016 | D(real): 0.875 | D(fake): 0.063
# Epoch 1977 | D loss: 21.621 | G loss: 82.013 | D(real): 0.716 | D(fake): 0.090
# Epoch 1978 | D loss: 23.094 | G loss: 62.729 | D(real): 0.825 | D(fake): 0.128
# Epoch 1979 | D loss: 13.800 | G loss: 59.877 | D(real): 0.807 | D(fake): 0.060
# Epoch 1980 | D loss: 21.108 | G loss: 73.911 | D(real): 0.752 | D(fake): 0.115
# Epoch 1981 | D loss: 21.112 | G loss: 71.159 | D(real): 0.862 | D(fake): 0.081
# Epoch 1982 | D loss: 22.972 | G loss: 85.911 | D(real): 0.732 | D(fake): 0.103
# Epoch 1983 | D loss: 24.723 | G loss: 89.388 | D(real): 0.835 | D(fake): 0.130
# Epoch 1984 | D loss: 16.973 | G loss: 79.431 | D(real): 0.790 | D(fake): 0.066
# Epoch 1985 | D loss: 13.316 | G loss: 62.469 | D(real): 0.877 | D(fake): 0.036
# Epoch 1986 | D loss: 8.997 | G loss: 55.637 | D(real): 0.871 | D(fake): 0.023
# Epoch 1987 | D loss: 32.793 | G loss: 70.611 | D(real): 0.716 | D(fake): 0.185
# Epoch 1988 | D loss: 24.535 | G loss: 115.868 | D(real): 0.819 | D(fake): 0.063
# Epoch 1989 | D loss: 22.521 | G loss: 78.266 | D(real): 0.805 | D(fake): 0.111
# Epoch 1990 | D loss: 24.579 | G loss: 92.866 | D(real): 0.777 | D(fake): 0.073
# Epoch 1991 | D loss: 23.784 | G loss: 97.091 | D(real): 0.800 | D(fake): 0.134
# Epoch 1992 | D loss: 33.515 | G loss: 90.077 | D(real): 0.729 | D(fake): 0.068
# Epoch 1993 | D loss: 28.997 | G loss: 113.154 | D(real): 0.781 | D(fake): 0.071
# Epoch 1994 | D loss: 39.270 | G loss: 100.789 | D(real): 0.801 | D(fake): 0.273
# Epoch 1995 | D loss: 24.353 | G loss: 143.691 | D(real): 0.819 | D(fake): 0.027
# Epoch 1996 | D loss: 42.450 | G loss: 101.956 | D(real): 0.802 | D(fake): 0.165
# Epoch 1997 | D loss: 37.810 | G loss: 150.966 | D(real): 0.754 | D(fake): 0.067
# Epoch 1998 | D loss: 23.154 | G loss: 130.776 | D(real): 0.879 | D(fake): 0.060
# Epoch 1999 | D loss: 18.327 | G loss: 109.352 | D(real): 0.838 | D(fake): 0.027
# Epoch 2000 | D loss: 28.377 | G loss: 100.287 | D(real): 0.778 | D(fake): 0.098

# %% [markdown]
# ### Paso 4.2 — Curvas de entrenamiento

# %%
# ── Curvas de pérdida ───────────────────────────────────────────────────
epochs_range = range(1, len(history["g_loss"]) + 1)

plt.figure(figsize=(7, 4))
plt.plot(epochs_range, history["d_loss"], marker="o", label="Discriminator loss")
plt.plot(epochs_range, history["g_loss"], marker="o", label="Generator loss")
plt.xlabel("Época")
plt.ylabel("Loss")
plt.title("Entrenamiento adversarial")
plt.legend()
plt.grid(alpha=0.3)
plt.show()

plt.figure(figsize=(7, 4))
plt.plot(epochs_range, history["d_real_score"], marker="o", label="D(real)")
plt.plot(epochs_range, history["d_fake_score"], marker="o", label="D(fake generado)")
plt.axhline(0.5, linestyle="--", linewidth=1)
plt.xlabel("Época")
plt.ylabel("Score promedio después de sigmoid")
plt.title("Comportamiento del discriminador")
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ---
#
# ## 5. Visualización de imágenes generadas
#
# Para visualizar imágenes generadas por una red con `tanh`, debemos convertirlas de `[-1, 1]` a `[0, 1]`:
#
# \[
# x_{vis} = \frac{x + 1}{2}
# \]

# %%
def generate_images(G, n_images=16, latent_dim=16, device="cpu"):
    G.eval()
    with torch.no_grad():
        # TODO 22: genera ruido latente y produce imágenes con G.
        z = torch.rand((32,latent_dim), device=device)
        generated = G.forward(z)


    # TODO 23: convierte de [-1, 1] a [0, 1] para visualizar.
    generated = torch.mul(torch.add(generated,1),0.5)
    generated = torch.clamp(generated, 0, 1)
    return generated

generated_images = generate_images(G, n_images=16, latent_dim=latent_dim, device=device)

show_image_grid(X_real, title="Imágenes reales sintéticas", n=16)
show_image_grid(generated_images, title="Imágenes generadas por la GAN", n=16)

# %% [markdown]
# ---
#
# ## 6. Evaluación básica de una GAN
#
# Una GAN no se evalúa igual que un clasificador.
# No hay etiquetas de clase ni matriz de confusión. En este challenge usaremos tres chequeos simples:
#
# 1. **Estadísticas de intensidad:** media y desviación estándar.
# 2. **Fracción de píxeles activos:** porcentaje de píxeles con intensidad mayor a 0.35.
# 3. **Diversidad:** distancia promedio entre imágenes generadas.
#
# Estas métricas no reemplazan evaluación clínica, pero ayudan a detectar fallas evidentes.

# %%
def pairwise_diversity(images):
    if isinstance(images, torch.Tensor):
        images = images.detach().cpu().numpy()
    flat = images.reshape(images.shape[0], -1)
    dists = []
    for i in range(len(flat)):
        for j in range(i + 1, len(flat)):
            dists.append(np.linalg.norm(flat[i] - flat[j]))
    return float(np.mean(dists))


real_sample = torch.tensor(X_real[:64])
gen_sample = generate_images(G, n_images=64, latent_dim=latent_dim, device=device)

# TODO 24: completa las estadísticas básicas para comparar reales vs generadas.
summary = pd.DataFrame({
    "Conjunto": ["Real sintético", "Generado"],
    "Intensidad media": [np.mean(real_sample.cpu().numpy()), np.mean(gen_sample.cpu().numpy())],
    "Desv. estándar": [np.std(real_sample.cpu().numpy()), np.std(gen_sample.cpu().numpy())],
    "Píxeles activos > 0.35": [np.sum(real_sample.cpu().numpy()>0.35), np.sum(gen_sample.cpu().numpy()>0.35)],
    "Diversidad promedio": ["Real sintético", "Generado"]
})

summary
# Out:
#          Conjunto  Intensidad media  Desv. estándar  Píxeles activos > 0.35  \
# 0  Real sintético          0.159872        0.135579                    3180
# 1        Generado          0.178522        0.140268                    2297
#
#   Diversidad promedio
# 0      Real sintético
# 1            Generado

# %% [markdown]
# ### Paso 6.2 — Chequeo de sobreajuste visual: vecino real más cercano
#
# Un riesgo de modelos generativos es memorizar ejemplos.
# Como chequeo simple, compararemos una imagen generada con la imagen real más cercana en distancia euclidiana.

# %%
def nearest_real_image(generated_img, real_images):
    # generated_img: (1, H, W), real_images: (N, 1, H, W), ambos en [0, 1]

    # TODO 25: aplana imagen generada e imágenes reales.
    gen_flat = torch.from_numpy(generated_img).flatten(1,-1).numpy()
    real_flat = torch.from_numpy(real_images).flatten(2,-1).numpy()

    # TODO 26: calcula distancias euclidianas y selecciona el índice menor.
    distances = [np.sqrt(np.sum((gen_flat-rfelement)**2) ) for rfelement in real_flat]
    idx = np.argmin(distances)
    return idx, distances[idx]

gen_np = gen_sample[0].cpu().numpy()
idx_near, dist_near = nearest_real_image(gen_np, X_real)

plt.figure(figsize=(6, 3))
plt.subplot(1, 2, 1)
plt.imshow(np.squeeze(gen_np), cmap="gray", vmin=0, vmax=1)
plt.title("Generada")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(np.squeeze(X_real[idx_near]), cmap="gray", vmin=0, vmax=1)
plt.title(f"Real más cercana\nDistancia={dist_near:.2f}")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 7. Interpretación final
#
# ### 7.1 — Análisis visual
#
# **Pregunta F1:** Describe brevemente si las imágenes generadas se parecen al dataset real.
#
# Respuesta:
# .Tienen similitud con el dataset, si bien son fáciles de distinguir a simple vista y es notorio que no se conservan atributos clave como las formas de las distribuciones gaussianas.
#
# ### 7.2 — Entrenamiento adversarial
#
# **Pregunta F2:** ¿Por qué en una GAN no basta con mirar solo la pérdida del generador?
#
# Respuesta:
# .Debido a que la pérdida del generador depende de las capacidades del discriminador, que debería poder observarse también.
#
# ### 7.3 — Riesgo clínico
#
# **Pregunta F3:** Menciona dos riesgos de usar imágenes sintéticas en un contexto biomédico.
#
# Respuesta:
# 1. .Potencial de introducir sesgo al modelo de diagnóstico, si es que los datos de entrenamiento del GAN no son representativos de la población objetivo.
# 2. .Disminución de sensibilidad a detalles al introducir imágenes de carácter genérico.
#
# ### 7.4 — Posible mejora
#
# **Pregunta F4:** Propón una mejora para este modelo si se quisiera avanzar hacia imágenes biomédicas más realistas.
#
# Respuesta:
# .Usar una arquitectua similar a las redes convolucionales residuales para el generador y otra similar a en el discriminador pero con mayor énfasis en capas lineales para la detección de detalles y sensibilidad.
