# %% [markdown]
# <a href="https://colab.research.google.com/github/RenzoLA26/Challenges/blob/main/Challenge7_LUNA_GALVAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style='background:#8B0000; padding:20px; border-radius:8px; margin-bottom:10px'>
# <h1 style='color:white; text-align:center; margin:0'>Reconocimiento de Patrones</h1>
# <h2 style='color:#ffcccc; text-align:center; margin:5px 0 0 0'>Challenge 7 — Redes Neuronales Convolucionales para Imágenes Biomédicas</h2>
# <p style='color:#ffaaaa; text-align:center; margin:5px 0 0 0'>Ingeniería Biomédica · UPCH · 2026-1</p>
# </div>
#
# > **Nota para estudiantes:** las celdas con `TODO` indican exactamente qué deben completar. Las pistas orientan el razonamiento, pero no reemplazan la interpretación clínica.

# %% [markdown]
# ## Contexto clínico
#
# En el Challenge 6 entrenaste un **perceptrón** y un **MLP** usando variables tabulares del dataset Breast Cancer Wisconsin. Ahora pasamos de datos tabulares a **imágenes biomédicas**.
#
# Trabajaremos con **PneumoniaMNIST**, un dataset de imágenes de radiografía de tórax en escala de grises, reducido a 28×28 píxeles, con dos clases:
#
# - `0 = Normal`
# - `1 = Pneumonia`
#
# El objetivo será entrenar modelos en **PyTorch** para distinguir entre radiografías normales y radiografías con neumonía. Primero construiremos un **baseline MLP** que aplana la imagen y luego una **CNN** que conserva la estructura espacial.
#
# **Pregunta clínica:** ¿por qué una CNN debería ser más adecuada que un MLP cuando la entrada es una imagen? ¿Qué error clínico es más crítico: clasificar una neumonía como normal o clasificar un caso normal como neumonía?
#
# ---
# > **Dataset:** PneumoniaMNIST, colección MedMNIST.
# > Se descarga directamente desde Python usando la librería `medmnist`.

# %% [markdown]
# <div style='background:#e8f5e9; padding:8px 14px; border-left:4px solid #2e7d32; border-radius:4px; margin:8px 0'>
# 🧑‍🎓 <b>VERSIÓN ESTUDIANTE</b> — completa los espacios en blanco, ejecuta el notebook en orden y responde las preguntas de interpretación clínica.
# </div>

# %% [markdown]
# ---
# ## Ejercicio 1 — Diseño previo al código
#
# ### 1.1 — De MLP a CNN
#
# <div style='background:#e8f5e9; padding:8px 14px; border-left:4px solid #2e7d32; border-radius:4px; margin:8px 0'>
# ⏱️ <b>EN CLASE</b> — responde antes de programar
# </div>
#
# **📝 Tu respuesta (edita esta celda):**
#
# > **TODO:** responde con 2–3 líneas por pregunta. Usa conceptos de CNN, MLP y métricas clínicas.
#
# **1. ¿Qué problema tiene usar un MLP directamente sobre una imagen?**
# _Hay demasiadas conexiones y por lo tanto parámetros a ser optimizados, lo que demanda muchos recursos computacionales, y no necesariamente toda la información es relevante._
#
# ---
#
# **2. ¿Qué ventaja tiene una CNN?**
# _Permite que entre capas, ocurra una detección de patrones localizada a regiones de la imagen, lo que permite reducir las conexiones y asociar pixeles cercanos más estrechamente, lo que le permitirá al modelo detectar geometrías y formas de manera más eficiente, permitiéndole reducir la dimensionalidad del problema._
#
# ---
#
# **3. ¿Qué podría representar un filtro convolucional en una radiografía de tórax?**
# _La detección de patrones de cambio en la luminosidad, pudiendo detectar regiones con poca variación de intensidad o las zonas donde la variación de intensidad es mayor, como en los bordes._

# %% [markdown]
# ### 1.2 — Convolución, pooling y clasificación
#
# <div style='background:#e8f5e9; padding:8px 14px; border-left:4px solid #2e7d32; border-radius:4px; margin:8px 0'>
# ⏱️ <b>EN CLASE</b> — responde con tus palabras
# </div>
#
# **📝 Tu respuesta (edita esta celda):**
#
# > **TODO:** responde con 2–3 líneas por pregunta. Usa conceptos de CNN, MLP y métricas clínicas.
#
# **1. ¿Qué produce una capa convolucional?**
# _Al aplicar una forma de convolución y asociar solo los pixeles o elementos más cercanos entre sí para la producción de la salida, permite que se detecten estructuras compatibles con el kernel, y se produce una imagen filtrada._
#
# **2. ¿Para qué sirve MaxPooling?**
# _Sirve como una forma de undersampling, disminuye la dimensionalidad de los outputs de una capa  para reducir la dimensionalidad y mantener la información más relevante extraída._
#
# **3. ¿Por qué al final usamos una capa lineal?**
# _Para que el modelo utilice todos los parámetros más importantes en la producción de la salida, una vez que las capas convolucionales y el pooling hayan resumido la información a la más importante._
#
# **4. ¿Por qué seguimos usando `BCEWithLogitsLoss`?**
# _Debido a que este es un problema de clasificación binaria y esta es la función de pérdida más apropiada._

# %% [markdown]
# ### 1.3 — Pipeline completo
#
# **TODO:** completa cada paso del pipeline con una frase breve.
#
# Completa el siguiente pipeline:
#
# ```text
# PneumoniaMNIST
#       │
#       ▼
# [ Paso A ] _Normalización / preprocesamiento_
#       │
#       ▼
# [ Paso B ] _EDA_
#       │
#       ▼
# [ Paso C ] _Funciones_
#       │
#       ▼
# [ Paso D ] _Entrenamiento de modelos_
#       │
#       ▼
# [ Paso E ] _Visualización de ajuste_
#       │
#       ▼
# [ Paso F ] _Comparación del ajuste_
#       │
#       ▼
# [ Paso G ] _Comparación de métricas_
#       │
#       ▼
# [ Paso H ] _Resultado final_
# ```
#
# **📝 Pregunta:** ¿por qué conviene entrenar primero un MLP baseline antes de entrenar la CNN?
# _Para verificar si el problema puede se mejor solucionado con asociaciónes más dispersas entre pixeles y si CNN es la mejor opción._

# %% [markdown]
# ---
# ## Ejercicio 2 — Setup y carga de datos
#
# <div style='background:#e8f5e9; padding:8px 14px; border-left:4px solid #2e7d32; border-radius:4px; margin:8px 0'>
# ⏱️ <b>EN CLASE</b> — completa esto durante la sesión
# </div>

# %% [markdown]
# ### Paso 2.1 — Librerías

# %%
# ── Instalación robusta de MedMNIST ─────────────────────────────
# En Google Colab debería ejecutarse sin problemas.
import importlib.util
import subprocess
import sys

if importlib.util.find_spec("medmnist") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "medmnist"])

# ── Colores institucionales UPCH ───────────────────────────────
UPCH_RED    = '#8B0000'
UPCH_BLUE   = '#1565C0'
UPCH_GREEN  = '#2E7D32'
UPCH_ORANGE = '#E65100'
UPCH_PURPLE = '#6A1B9A'
UPCH_GRAY   = '#4A4A4A'

# ── Librerías base ──────────────────────────────────────────────
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ── PyTorch ─────────────────────────────────────────────────────
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms

# ── Dataset MedMNIST ────────────────────────────────────────────
from medmnist import PneumoniaMNIST, INFO

# ── Métricas ────────────────────────────────────────────────────
from sklearn.metrics import (
    confusion_matrix, accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, roc_curve
)

sns.set_context("notebook")
plt.rcParams['figure.figsize'] = (7, 4)

def seed_everything(seed=42):
    """Fija semillas para reproducibilidad."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

seed_everything(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cpu

# %% [markdown]
# ### Paso 2.2 — Transformaciones y carga de PneumoniaMNIST

# %%
# ── Información del dataset ─────────────────────────────────────
info = INFO['pneumoniamnist']
print("Descripción:", info['description'][:300], "...")
print("Clases:", info['label'])
print("Canales:", info['n_channels'])

# ── Transformación: PIL/NumPy → Tensor normalizado ──────────────
# TODO 1: completa mean y std para una imagen en escala de grises.
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

# ── Carga de splits oficiales ───────────────────────────────────
train_dataset = PneumoniaMNIST(split='train', transform=transform, download=True)
val_dataset   = PneumoniaMNIST(split='val',   transform=transform, download=True)
test_dataset  = PneumoniaMNIST(split='test',  transform=transform, download=True)

print(f"Train: {len(train_dataset)} imágenes")
print(f"Val:   {len(val_dataset)} imágenes")
print(f"Test:  {len(test_dataset)} imágenes")

sample_img, sample_label = train_dataset[0]

#print(sample_img.numpy().max())

print("Forma de una imagen:", sample_img.shape)
print("Etiqueta ejemplo:", int(sample_label[0]))
# Out:
# Descripción: The PneumoniaMNIST is based on a prior dataset of 5,856 pediatric chest X-Ray images. The task is binary-class classification of pneumonia against normal. We split the source training set with a ratio of 9:1 into training and validation set and use its source validation set as the test set. The sour ...
# Clases: {'0': 'normal', '1': 'pneumonia'}
# Canales: 1
# Train: 4708 imágenes
# Val:   524 imágenes
# Test:  624 imágenes
# 0.7647059
# Forma de una imagen: torch.Size([1, 28, 28])
# Etiqueta ejemplo: 1

# %% [markdown]
# ### Paso 2.3 — Distribución de clases y visualización inicial

# %%
# ── Distribución de clases ──────────────────────────────────────
label_map = {0: "Normal", 1: "Pneumonia"}

def get_label_array(dataset):
    return dataset.labels.reshape(-1).astype(int)

train_labels = get_label_array(train_dataset)
val_labels   = get_label_array(val_dataset)
test_labels  = get_label_array(test_dataset)

dist_df = pd.DataFrame({
    "split": ["train"] * len(train_labels) + ["val"] * len(val_labels) + ["test"] * len(test_labels),
    "label": np.concatenate([train_labels, val_labels, test_labels])
})
dist_df["class_name"] = dist_df["label"].map(label_map)

display(pd.crosstab(dist_df["split"], dist_df["class_name"]))

fig, ax = plt.subplots(figsize=(7, 4))
sns.countplot(data=dist_df, x="split", hue="class_name", ax=ax)
ax.set_title("Distribución de clases por split")
ax.set_xlabel("Split")
ax.set_ylabel("Número de imágenes")
plt.show()
# Out:
# class_name  Normal  Pneumonia
# split
# test           234        390
# train         1214       3494
# val            135        389

# %%
# ── Visualización de ejemplos ───────────────────────────────────
def unnormalize_img(img_tensor):
    """Convierte tensor normalizado [-1,1] a imagen [0,1] para visualizar."""
    return (img_tensor.squeeze().cpu().numpy() * 0.5) + 0.5

def plot_class_examples(dataset, n_per_class=6):
    labels = get_label_array(dataset)
    fig, axes = plt.subplots(2, n_per_class, figsize=(14, 5))

    for class_id in [0, 1]:
        idxs = np.where(labels == class_id)[0]
        chosen = np.random.choice(idxs, size=n_per_class, replace=False)

        for j, idx in enumerate(chosen):
            img, label = dataset[idx]
            axes[class_id, j].imshow(unnormalize_img(img), cmap="gray")
            axes[class_id, j].axis("off")
            axes[class_id, j].set_title(label_map[int(label[0])])

    plt.suptitle("Ejemplos de imágenes — PneumoniaMNIST")
    plt.tight_layout()
    plt.show()

plot_class_examples(train_dataset, n_per_class=6)

# %% [markdown]
# ### Paso 2.4 — Interpretación inicial
#
# **📝 Tu respuesta (edita esta celda):**
#
# > **TODO:** responde con 2–3 líneas por pregunta. Usa conceptos de CNN, MLP y métricas clínicas.
#
# **1. ¿Qué forma tiene cada imagen y qué significa cada dimensión?**
# _1,28,28. El 1 significa que tiene un solo canal, y los 28 son la altura y ancho._
#
# **2. ¿Observas desbalance de clases? ¿Por qué importa?**
# _Sí, porque el desbalance puede sesgar sesgar al modelo a asumir que la distribución de clases es igual a la del train, a pesar que no la sea para val y test, por lo que los resultados de evaluarlo no reflejarían el ajuste._
#
# **3. En este problema, ¿qué sería un falso negativo?**
# _Un falso negativo sería un paciente con neumonía que es clasificado como sin neumonía._
#
# **4. ¿Por qué una CNN puede ser apropiada para este tipo de dato?**
# _Debido a que puede asociar los pixeles más cercanos entre sí y detectar más fácilmente las características geométricas de la imagen como la forma de la zona sospechosa, de haberla, y su tamaño._

# %% [markdown]
# ---
# # PARTE 1 — DataLoader y mini-batches de imágenes
# ## Ejercicio 3 — Preparación de mini-batches
#
# <div style='background:#e8f5e9; padding:8px 14px; border-left:4px solid #2e7d32; border-radius:4px; margin:8px 0'>
# ⏱️ <b>EN CLASE</b> — completa esto durante la sesión
# </div>

# %% [markdown]
# ### Paso 3.1 — Creación de DataLoaders

# %%
# ── DataLoaders ─────────────────────────────────────────────────
# TODO 2: define un tamaño de mini-batch y el orden de mezcla.
BATCH_SIZE = 50

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

xb, yb = next(iter(train_loader))

print("Mini-batch de imágenes:", xb.shape)
print("Mini-batch de etiquetas:", yb.shape)
print("Tipo de dato X:", xb.dtype)
print("Tipo de dato y:", yb.dtype)
# Out:
# Mini-batch de imágenes: torch.Size([50, 1, 28, 28])
# Mini-batch de etiquetas: torch.Size([50, 1])
# Tipo de dato X: torch.float32
# Tipo de dato y: torch.int64

# %% [markdown]
# ### Paso 3.2 — ¿Qué significa la forma del tensor?

# %%
# ── Interpretación de dimensiones ───────────────────────────────
# TODO 3: completa los prints usando las variables B, C, H y W.
B, C, H, W = xb.shape
print(f"B = {B} imágenes por mini-batch")
print(f"C = {C} canal(es) de imagen")
print(f"H = {H} píxeles de alto")
print(f"W = {W} píxeles de ancho")
# Out:
# B = 50 imágenes por mini-batch
# C = 1 canal(es) de imagen
# H = 28 píxeles de alto
# W = 28 píxeles de ancho

# %% [markdown]
# ### Paso 3.3 — Interpretación
#
# **📝 Tu respuesta (edita esta celda):**
#
# > **TODO:** responde con 2–3 líneas por pregunta. Usa conceptos de CNN, MLP y métricas clínicas.
#
# **1. ¿Qué significa el formato `[batch, channels, height, width]`?**
# _Es el orden de las dimensiones de un tensor de batch. La primera dimensión indica los batches, la segunda el canal de la imagen, la tercera _
#
# **2. ¿Por qué PneumoniaMNIST tiene un solo canal?**
# _Debido a que consiste en imágenes radiográficas, y están en escala de grises, por lo que no se necesitan 3 canales como en imágenes a color._
#
# **3. ¿Por qué entrenamos con mini-batches en lugar de procesar todo el dataset de una sola vez?**
# _Debido a que requiere de menos cálculos para un paso de gradiente descendiente y permite una mayor variabilidad en por paso que el procesamiento de todo el dataset, permitiendo escapar de mínimos relativos._

# %% [markdown]
# ---
# # PARTE 2 — Baseline MLP con imagen aplanada
# ## Ejercicio 4 — Modelo MLP para comparar contra CNN
#
# <div style='background:#e8f5e9; padding:8px 14px; border-left:4px solid #2e7d32; border-radius:4px; margin:8px 0'>
# ⏱️ <b>EN CLASE</b> — completa esto durante la sesión
# </div>

# %% [markdown]
# ### Paso 4.1 — Definición del baseline MLP

# %%
# ── Baseline: MLP que aplana la imagen ──────────────────────────
# TODO 4: completa las dimensiones del MLP.
class FlattenMLP(nn.Module):
    def __init__(self):
        super().__init__()

        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28*28, 28*28),  # TODO 4.1: capa de entrada → capa oculta
            nn.ReLU(),
            nn.Linear(28*28, 1)   # TODO 4.2: capa oculta → 1 logit
        )

    def forward(self, x):
        return self.net(x)

mlp_model = FlattenMLP().to(device)
print(mlp_model)
# Out:
# FlattenMLP(
#   (net): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=784, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=784, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ### Paso 4.2 — Funciones generales de entrenamiento y evaluación
#
# <div style='background:#e8f5e9; padding:8px 14px; border-left:4px solid #2e7d32; border-radius:4px; margin:8px 0'>
# ⏱️ <b>EN CLASE</b> — completa el cálculo de desbalance y el ciclo de entrenamiento
# </div>
#
# **Nota:** `pos_weight` ayuda a manejar desbalance en la función de pérdida, pero la decisión clínica final se analiza con sensibilidad, especificidad y umbrales.

# %%
# ── Conteo de parámetros ────────────────────────────────────────
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print("Parámetros del MLP:", count_parameters(mlp_model))

# ── Peso para clase positiva por desbalance ─────────────────────
# TODO 5: cuenta positivos y negativos usando train_labels.
# En este dataset: 0 = Normal, 1 = Pneumonia.
n_pos = (train_labels == 1).sum()
n_neg = (train_labels == 0).sum()
pos_weight = torch.tensor([n_neg / n_pos], dtype=torch.float32).to(device)

print(f"n_neg={n_neg}, n_pos={n_pos}, pos_weight={pos_weight.item():.3f}")

loss_fn = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

def train_one_epoch(model, loader, loss_fn, optimizer, device):
    model.train()

    total_loss = 0.0
    correct = 0
    n = 0

    for X_batch, y_batch in loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.float().view(-1, 1).to(device)

        # TODO 6: forward pass → pérdida → backpropagation → actualización
        logits = model(X_batch)
        loss = loss_fn(logits, y_batch)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * X_batch.size(0)

        probs = torch.sigmoid(logits)
        preds = (probs >= 0.5).float()
        correct += (preds == y_batch).sum().item()
        n += X_batch.size(0)

    return total_loss / n, correct / n


@torch.no_grad()
def evaluate_one_epoch(model, loader, loss_fn, device):
    model.eval()

    total_loss = 0.0
    correct = 0
    n = 0

    for X_batch, y_batch in loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.float().view(-1, 1).to(device)

        logits = model(X_batch)
        loss = loss_fn(logits, y_batch)

        total_loss += loss.item() * X_batch.size(0)

        probs = torch.sigmoid(logits)
        preds = (probs >= 0.5).float()
        correct += (preds == y_batch).sum().item()
        n += X_batch.size(0)

    return total_loss / n, correct / n


def fit_model(model, train_loader, val_loader, loss_fn, optimizer, device, epochs=6):
    history = {
        "train_loss": [], "val_loss": [],
        "train_acc": [],  "val_acc": []
    }

    for epoch in range(1, epochs + 1):
        train_loss, train_acc = train_one_epoch(model, train_loader, loss_fn, optimizer, device)
        val_loss, val_acc     = evaluate_one_epoch(model, val_loader, loss_fn, device)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)

        print(
            f"Epoch {epoch:02d}/{epochs} | "
            f"train_loss={train_loss:.4f} | val_loss={val_loss:.4f} | "
            f"train_acc={train_acc:.3f} | val_acc={val_acc:.3f}"
        )

    return history


def plot_history(history, title):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(history["train_loss"], marker="o", label="train")
    axes[0].plot(history["val_loss"], marker="o", label="val")
    axes[0].set_title(f"{title} — Loss")
    axes[0].set_xlabel("Época")
    axes[0].set_ylabel("Loss")
    axes[0].legend()

    axes[1].plot(history["train_acc"], marker="o", label="train")
    axes[1].plot(history["val_acc"], marker="o", label="val")
    axes[1].set_title(f"{title} — Accuracy")
    axes[1].set_xlabel("Época")
    axes[1].set_ylabel("Accuracy")
    axes[1].legend()

    plt.tight_layout()
    plt.show()
# Out:
# Parámetros del MLP: 616225
# n_neg=1214, n_pos=3494, pos_weight=0.347

# %% [markdown]
# ### Paso 4.3 — Entrenamiento del MLP

# %%
# ── Entrenamiento del baseline MLP ──────────────────────────────
# TODO 7: define learning rate y número de épocas.
#         Pista: empieza con lr=1e-3 y pocas épocas para que sea rápido en clase.
seed_everything(42)

mlp_model = FlattenMLP().to(device)
mlp_optimizer = optim.Adam(mlp_model.parameters(), lr=1e-3)

mlp_history = fit_model(
    model=mlp_model,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_fn=loss_fn,
    optimizer=mlp_optimizer,
    device=device,
    epochs=150
)

plot_history(mlp_history, "Baseline MLP")
# Out:
# Epoch 01/150 | train_loss=0.1095 | val_loss=0.0798 | train_acc=0.905 | val_acc=0.950
# Epoch 02/150 | train_loss=0.0713 | val_loss=0.0647 | train_acc=0.948 | val_acc=0.948
# Epoch 03/150 | train_loss=0.0633 | val_loss=0.0677 | train_acc=0.952 | val_acc=0.954
# Epoch 04/150 | train_loss=0.0580 | val_loss=0.0552 | train_acc=0.960 | val_acc=0.950
# Epoch 05/150 | train_loss=0.0511 | val_loss=0.0727 | train_acc=0.960 | val_acc=0.931
# Epoch 06/150 | train_loss=0.0445 | val_loss=0.0597 | train_acc=0.967 | val_acc=0.952
# Epoch 07/150 | train_loss=0.0480 | val_loss=0.0659 | train_acc=0.964 | val_acc=0.958
# Epoch 08/150 | train_loss=0.0460 | val_loss=0.0729 | train_acc=0.963 | val_acc=0.931
# Epoch 09/150 | train_loss=0.0378 | val_loss=0.0526 | train_acc=0.972 | val_acc=0.966
# Epoch 10/150 | train_loss=0.0320 | val_loss=0.0708 | train_acc=0.977 | val_acc=0.947
# Epoch 11/150 | train_loss=0.0283 | val_loss=0.0662 | train_acc=0.981 | val_acc=0.939
# Epoch 12/150 | train_loss=0.0300 | val_loss=0.0697 | train_acc=0.977 | val_acc=0.947
# Epoch 13/150 | train_loss=0.0301 | val_loss=0.0694 | train_acc=0.976 | val_acc=0.935
# Epoch 14/150 | train_loss=0.0253 | val_loss=0.0594 | train_acc=0.982 | val_acc=0.952
# Epoch 15/150 | train_loss=0.0209 | val_loss=0.0696 | train_acc=0.987 | val_acc=0.958
# Epoch 16/150 | train_loss=0.0200 | val_loss=0.0742 | train_acc=0.985 | val_acc=0.962
# Epoch 17/150 | train_loss=0.0240 | val_loss=0.0654 | train_acc=0.979 | val_acc=0.947
# Epoch 18/150 | train_loss=0.0177 | val_loss=0.0820 | train_acc=0.986 | val_acc=0.954
# Epoch 19/150 | train_loss=0.0193 | val_loss=0.1030 | train_acc=0.983 | val_acc=0.958
# Epoch 20/150 | train_loss=0.0237 | val_loss=0.0665 | train_acc=0.983 | val_acc=0.956
# Epoch 21/150 | train_loss=0.0175 | val_loss=0.0699 | train_acc=0.988 | val_acc=0.954
# Epoch 22/150 | train_loss=0.0239 | val_loss=0.0606 | train_acc=0.981 | val_acc=0.964
# Epoch 23/150 | train_loss=0.0125 | val_loss=0.0883 | train_acc=0.990 | val_acc=0.948
# Epoch 24/150 | train_loss=0.0133 | val_loss=0.0899 | train_acc=0.990 | val_acc=0.958
# Epoch 25/150 | train_loss=0.0095 | val_loss=0.0709 | train_acc=0.993 | val_acc=0.956
# Epoch 26/150 | train_loss=0.0068 | val_loss=0.0812 | train_acc=0.996 | val_acc=0.954
# Epoch 27/150 | train_loss=0.0054 | val_loss=0.1131 | train_acc=0.997 | val_acc=0.958
# Epoch 28/150 | train_loss=0.0055 | val_loss=0.0868 | train_acc=0.996 | val_acc=0.966
# Epoch 29/150 | train_loss=0.0045 | val_loss=0.1015 | train_acc=0.997 | val_acc=0.962
# Epoch 30/150 | train_loss=0.0097 | val_loss=0.0926 | train_acc=0.994 | val_acc=0.950
# Epoch 31/150 | train_loss=0.0072 | val_loss=0.0983 | train_acc=0.995 | val_acc=0.966
# Epoch 32/150 | train_loss=0.0034 | val_loss=0.0843 | train_acc=0.998 | val_acc=0.962
# Epoch 33/150 | train_loss=0.0024 | val_loss=0.0877 | train_acc=0.999 | val_acc=0.964
# Epoch 34/150 | train_loss=0.0018 | val_loss=0.1056 | train_acc=1.000 | val_acc=0.958
# Epoch 35/150 | train_loss=0.0017 | val_loss=0.0949 | train_acc=0.999 | val_acc=0.964
# Epoch 36/150 | train_loss=0.0012 | val_loss=0.1017 | train_acc=1.000 | val_acc=0.962
# Epoch 37/150 | train_loss=0.0011 | val_loss=0.1064 | train_acc=1.000 | val_acc=0.960
# Epoch 38/150 | train_loss=0.0010 | val_loss=0.1047 | train_acc=1.000 | val_acc=0.964
# Epoch 39/150 | train_loss=0.0012 | val_loss=0.0937 | train_acc=1.000 | val_acc=0.968
# Epoch 40/150 | train_loss=0.0010 | val_loss=0.1123 | train_acc=1.000 | val_acc=0.962
# Epoch 41/150 | train_loss=0.0006 | val_loss=0.1077 | train_acc=1.000 | val_acc=0.968
# Epoch 42/150 | train_loss=0.0005 | val_loss=0.1093 | train_acc=1.000 | val_acc=0.962
# Epoch 43/150 | train_loss=0.0005 | val_loss=0.1053 | train_acc=1.000 | val_acc=0.966
# Epoch 44/150 | train_loss=0.0004 | val_loss=0.1120 | train_acc=1.000 | val_acc=0.964
# Epoch 45/150 | train_loss=0.0004 | val_loss=0.1239 | train_acc=1.000 | val_acc=0.956
# Epoch 46/150 | train_loss=0.0004 | val_loss=0.1137 | train_acc=1.000 | val_acc=0.964
# Epoch 47/150 | train_loss=0.0004 | val_loss=0.1149 | train_acc=1.000 | val_acc=0.968
# Epoch 48/150 | train_loss=0.0003 | val_loss=0.1176 | train_acc=1.000 | val_acc=0.962
# Epoch 49/150 | train_loss=0.0003 | val_loss=0.1172 | train_acc=1.000 | val_acc=0.966
# Epoch 50/150 | train_loss=0.0003 | val_loss=0.1176 | train_acc=1.000 | val_acc=0.968
# Epoch 51/150 | train_loss=0.0002 | val_loss=0.1249 | train_acc=1.000 | val_acc=0.962
# Epoch 52/150 | train_loss=0.0002 | val_loss=0.1212 | train_acc=1.000 | val_acc=0.966
# Epoch 53/150 | train_loss=0.0002 | val_loss=0.1265 | train_acc=1.000 | val_acc=0.962
# Epoch 54/150 | train_loss=0.0002 | val_loss=0.1237 | train_acc=1.000 | val_acc=0.966
# Epoch 55/150 | train_loss=0.0002 | val_loss=0.1310 | train_acc=1.000 | val_acc=0.960
# Epoch 56/150 | train_loss=0.0002 | val_loss=0.1243 | train_acc=1.000 | val_acc=0.966
# Epoch 57/150 | train_loss=0.0001 | val_loss=0.1297 | train_acc=1.000 | val_acc=0.960
# Epoch 58/150 | train_loss=0.0002 | val_loss=0.1334 | train_acc=1.000 | val_acc=0.960
# Epoch 59/150 | train_loss=0.0001 | val_loss=0.1278 | train_acc=1.000 | val_acc=0.964
# Epoch 60/150 | train_loss=0.0001 | val_loss=0.1290 | train_acc=1.000 | val_acc=0.966
# Epoch 61/150 | train_loss=0.0001 | val_loss=0.1285 | train_acc=1.000 | val_acc=0.966
# Epoch 62/150 | train_loss=0.0001 | val_loss=0.1369 | train_acc=1.000 | val_acc=0.962
# Epoch 63/150 | train_loss=0.0001 | val_loss=0.1352 | train_acc=1.000 | val_acc=0.962
# Epoch 64/150 | train_loss=0.0001 | val_loss=0.1356 | train_acc=1.000 | val_acc=0.962
# Epoch 65/150 | train_loss=0.0001 | val_loss=0.1364 | train_acc=1.000 | val_acc=0.964
# Epoch 66/150 | train_loss=0.0001 | val_loss=0.1388 | train_acc=1.000 | val_acc=0.962
# Epoch 67/150 | train_loss=0.0001 | val_loss=0.1340 | train_acc=1.000 | val_acc=0.966
# Epoch 68/150 | train_loss=0.0001 | val_loss=0.1414 | train_acc=1.000 | val_acc=0.962
# Epoch 69/150 | train_loss=0.0001 | val_loss=0.1423 | train_acc=1.000 | val_acc=0.964
# Epoch 70/150 | train_loss=0.0001 | val_loss=0.1468 | train_acc=1.000 | val_acc=0.962
# Epoch 71/150 | train_loss=0.0001 | val_loss=0.1428 | train_acc=1.000 | val_acc=0.964
# Epoch 72/150 | train_loss=0.0001 | val_loss=0.1469 | train_acc=1.000 | val_acc=0.962
# Epoch 73/150 | train_loss=0.0001 | val_loss=0.1486 | train_acc=1.000 | val_acc=0.964
# Epoch 74/150 | train_loss=0.0000 | val_loss=0.1442 | train_acc=1.000 | val_acc=0.964
# Epoch 75/150 | train_loss=0.0000 | val_loss=0.1490 | train_acc=1.000 | val_acc=0.964
# Epoch 76/150 | train_loss=0.0000 | val_loss=0.1460 | train_acc=1.000 | val_acc=0.964
# Epoch 77/150 | train_loss=0.0000 | val_loss=0.1457 | train_acc=1.000 | val_acc=0.966
# Epoch 78/150 | train_loss=0.0000 | val_loss=0.1491 | train_acc=1.000 | val_acc=0.964
# Epoch 79/150 | train_loss=0.0000 | val_loss=0.1485 | train_acc=1.000 | val_acc=0.964
# Epoch 80/150 | train_loss=0.0000 | val_loss=0.1521 | train_acc=1.000 | val_acc=0.962
# Epoch 81/150 | train_loss=0.0000 | val_loss=0.1554 | train_acc=1.000 | val_acc=0.962
# Epoch 82/150 | train_loss=0.0000 | val_loss=0.1523 | train_acc=1.000 | val_acc=0.964
# Epoch 83/150 | train_loss=0.0000 | val_loss=0.1566 | train_acc=1.000 | val_acc=0.966
# Epoch 84/150 | train_loss=0.0000 | val_loss=0.1559 | train_acc=1.000 | val_acc=0.962
# Epoch 85/150 | train_loss=0.0000 | val_loss=0.1558 | train_acc=1.000 | val_acc=0.964
# Epoch 86/150 | train_loss=0.0000 | val_loss=0.1539 | train_acc=1.000 | val_acc=0.964
# Epoch 87/150 | train_loss=0.0000 | val_loss=0.1533 | train_acc=1.000 | val_acc=0.964
# Epoch 88/150 | train_loss=0.0000 | val_loss=0.1553 | train_acc=1.000 | val_acc=0.964
# Epoch 89/150 | train_loss=0.0392 | val_loss=0.2771 | train_acc=0.985 | val_acc=0.922
# Epoch 90/150 | train_loss=0.0820 | val_loss=0.1675 | train_acc=0.963 | val_acc=0.914
# Epoch 91/150 | train_loss=0.0271 | val_loss=0.1140 | train_acc=0.983 | val_acc=0.956
# Epoch 92/150 | train_loss=0.0105 | val_loss=0.0947 | train_acc=0.995 | val_acc=0.958
# Epoch 93/150 | train_loss=0.0080 | val_loss=0.0801 | train_acc=0.997 | val_acc=0.956
# Epoch 94/150 | train_loss=0.0032 | val_loss=0.0942 | train_acc=0.999 | val_acc=0.960
# Epoch 95/150 | train_loss=0.0016 | val_loss=0.1022 | train_acc=1.000 | val_acc=0.962
# Epoch 96/150 | train_loss=0.0012 | val_loss=0.1021 | train_acc=1.000 | val_acc=0.958
# Epoch 97/150 | train_loss=0.0011 | val_loss=0.1062 | train_acc=1.000 | val_acc=0.962
# Epoch 98/150 | train_loss=0.0009 | val_loss=0.1051 | train_acc=1.000 | val_acc=0.962
# Epoch 99/150 | train_loss=0.0008 | val_loss=0.1123 | train_acc=1.000 | val_acc=0.958
# Epoch 100/150 | train_loss=0.0008 | val_loss=0.1071 | train_acc=1.000 | val_acc=0.962
# Epoch 101/150 | train_loss=0.0006 | val_loss=0.1125 | train_acc=1.000 | val_acc=0.960
# Epoch 102/150 | train_loss=0.0006 | val_loss=0.1116 | train_acc=1.000 | val_acc=0.962
# Epoch 103/150 | train_loss=0.0005 | val_loss=0.1113 | train_acc=1.000 | val_acc=0.958
# Epoch 104/150 | train_loss=0.0005 | val_loss=0.1146 | train_acc=1.000 | val_acc=0.960
# Epoch 105/150 | train_loss=0.0004 | val_loss=0.1120 | train_acc=1.000 | val_acc=0.960
# Epoch 106/150 | train_loss=0.0004 | val_loss=0.1191 | train_acc=1.000 | val_acc=0.960
# Epoch 107/150 | train_loss=0.0004 | val_loss=0.1147 | train_acc=1.000 | val_acc=0.960
# Epoch 108/150 | train_loss=0.0003 | val_loss=0.1178 | train_acc=1.000 | val_acc=0.958
# Epoch 109/150 | train_loss=0.0003 | val_loss=0.1161 | train_acc=1.000 | val_acc=0.960
# Epoch 110/150 | train_loss=0.0003 | val_loss=0.1178 | train_acc=1.000 | val_acc=0.960
# Epoch 111/150 | train_loss=0.0003 | val_loss=0.1212 | train_acc=1.000 | val_acc=0.960
# Epoch 112/150 | train_loss=0.0002 | val_loss=0.1182 | train_acc=1.000 | val_acc=0.962
# Epoch 113/150 | train_loss=0.0002 | val_loss=0.1156 | train_acc=1.000 | val_acc=0.962
# Epoch 114/150 | train_loss=0.0002 | val_loss=0.1155 | train_acc=1.000 | val_acc=0.960
# Epoch 115/150 | train_loss=0.0002 | val_loss=0.1247 | train_acc=1.000 | val_acc=0.958
# Epoch 116/150 | train_loss=0.0002 | val_loss=0.1211 | train_acc=1.000 | val_acc=0.960
# Epoch 117/150 | train_loss=0.0002 | val_loss=0.1236 | train_acc=1.000 | val_acc=0.958
# Epoch 118/150 | train_loss=0.0002 | val_loss=0.1313 | train_acc=1.000 | val_acc=0.958
# Epoch 119/150 | train_loss=0.0002 | val_loss=0.1210 | train_acc=1.000 | val_acc=0.962
# Epoch 120/150 | train_loss=0.0001 | val_loss=0.1252 | train_acc=1.000 | val_acc=0.958
# Epoch 121/150 | train_loss=0.0001 | val_loss=0.1279 | train_acc=1.000 | val_acc=0.958
# Epoch 122/150 | train_loss=0.0001 | val_loss=0.1284 | train_acc=1.000 | val_acc=0.958
# Epoch 123/150 | train_loss=0.0001 | val_loss=0.1243 | train_acc=1.000 | val_acc=0.962
# Epoch 124/150 | train_loss=0.0001 | val_loss=0.1225 | train_acc=1.000 | val_acc=0.960
# Epoch 125/150 | train_loss=0.0001 | val_loss=0.1296 | train_acc=1.000 | val_acc=0.958
# Epoch 126/150 | train_loss=0.0001 | val_loss=0.1323 | train_acc=1.000 | val_acc=0.956
# Epoch 127/150 | train_loss=0.0001 | val_loss=0.1314 | train_acc=1.000 | val_acc=0.958
# Epoch 128/150 | train_loss=0.0001 | val_loss=0.1289 | train_acc=1.000 | val_acc=0.958
# Epoch 129/150 | train_loss=0.0001 | val_loss=0.1315 | train_acc=1.000 | val_acc=0.958
# Epoch 130/150 | train_loss=0.0001 | val_loss=0.1326 | train_acc=1.000 | val_acc=0.956
# Epoch 131/150 | train_loss=0.0001 | val_loss=0.1346 | train_acc=1.000 | val_acc=0.956
# Epoch 132/150 | train_loss=0.0001 | val_loss=0.1401 | train_acc=1.000 | val_acc=0.956
# Epoch 133/150 | train_loss=0.0001 | val_loss=0.1307 | train_acc=1.000 | val_acc=0.960
# Epoch 134/150 | train_loss=0.0001 | val_loss=0.1363 | train_acc=1.000 | val_acc=0.956
# Epoch 135/150 | train_loss=0.0001 | val_loss=0.1372 | train_acc=1.000 | val_acc=0.958
# Epoch 136/150 | train_loss=0.0001 | val_loss=0.1333 | train_acc=1.000 | val_acc=0.962
# Epoch 137/150 | train_loss=0.0001 | val_loss=0.1396 | train_acc=1.000 | val_acc=0.956
# Epoch 138/150 | train_loss=0.0001 | val_loss=0.1407 | train_acc=1.000 | val_acc=0.956
# Epoch 139/150 | train_loss=0.0001 | val_loss=0.1465 | train_acc=1.000 | val_acc=0.956
# Epoch 140/150 | train_loss=0.0000 | val_loss=0.1373 | train_acc=1.000 | val_acc=0.960
# Epoch 141/150 | train_loss=0.0000 | val_loss=0.1403 | train_acc=1.000 | val_acc=0.960
# Epoch 142/150 | train_loss=0.0000 | val_loss=0.1348 | train_acc=1.000 | val_acc=0.962
# Epoch 143/150 | train_loss=0.0000 | val_loss=0.1459 | train_acc=1.000 | val_acc=0.956
# Epoch 144/150 | train_loss=0.0000 | val_loss=0.1408 | train_acc=1.000 | val_acc=0.960
# Epoch 145/150 | train_loss=0.0000 | val_loss=0.1416 | train_acc=1.000 | val_acc=0.958
# Epoch 146/150 | train_loss=0.0000 | val_loss=0.1451 | train_acc=1.000 | val_acc=0.960
# Epoch 147/150 | train_loss=0.0000 | val_loss=0.1452 | train_acc=1.000 | val_acc=0.958
# Epoch 148/150 | train_loss=0.0000 | val_loss=0.1445 | train_acc=1.000 | val_acc=0.960
# Epoch 149/150 | train_loss=0.0000 | val_loss=0.1505 | train_acc=1.000 | val_acc=0.956
# Epoch 150/150 | train_loss=0.0000 | val_loss=0.1465 | train_acc=1.000 | val_acc=0.960

# %% [markdown]
# ### Paso 4.4 — Interpretación del baseline
#
# **📝 Tu respuesta (edita esta celda):**
#
# > **TODO:** responde con 2–3 líneas por pregunta. Usa conceptos de CNN, MLP y métricas clínicas.
#
# **1. ¿Qué información espacial pierde el MLP al aplanar la imagen?**
# _Las coordenadas relativas entre pixeles, que podrían haber denotado una estructura en la imagen. Se pierde la dependencia del espacio intrínseca._
#
# **2. ¿Por qué este MLP sirve como baseline y no necesariamente como mejor modelo final?**
# _Debido a que una estructura simple de red neuronal y no presenta las especializaciones que la CNN tiene, por lo que sirve para verificar la utilidad de CNNs en tareas específicas._

# %% [markdown]
# ---
# # PARTE 3 — CNN para clasificación de radiografías
# ## Ejercicio 5 — Modelo convolucional en PyTorch
#
# <div style='background:#fff3e0; padding:8px 14px; border-left:4px solid #e65100; border-radius:4px; margin:8px 0'>
# 📚 <b>TAREA</b> — completa esto antes de la siguiente clase
# </div>

# %% [markdown]
# ### Paso 5.1 — Definición de la CNN

# %%
# ── CNN simple para imágenes 28×28 en escala de grises ──────────
# TODO 8: completa la arquitectura CNN.
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, padding=2),  # TODO 8.3  # TODO 8.1
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),  # TODO 8.4,  # TODO 8.2

            nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(7 * 7 * 6, 49),  # TODO 8.5: flatten features → capa oculta
            nn.ReLU(),
            nn.Linear(49, 1)  # TODO 8.6: capa oculta → 1 logit
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

cnn_model = SimpleCNN().to(device)
print(cnn_model)
print("Parámetros de la CNN:", count_parameters(cnn_model))
# Out:
# SimpleCNN(
#   (features): Sequential(
#     (0): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=294, out_features=49, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=49, out_features=1, bias=True)
#   )
# )
# Parámetros de la CNN: 14991

# %% [markdown]
# ### Paso 5.2 — Verificación de dimensiones con un mini-batch

# %%
# ── Sanity check de dimensiones ─────────────────────────────────
# TODO 9: pasa el mismo mini-batch por extractor de características y modelo completo.
xb, yb = next(iter(train_loader))
xb = xb.to(device)

with torch.no_grad():
    feature_maps = cnn_model.features(xb)
    logits = cnn_model(xb)

print("Entrada:", xb.shape)
print("Después de convoluciones + pooling:", feature_maps.shape)
print("Salida logits:", logits.shape)
# Out:
# Entrada: torch.Size([50, 1, 28, 28])
# Después de convoluciones + pooling: torch.Size([50, 6, 7, 7])
# Salida logits: torch.Size([50, 1])

# %% [markdown]
# ### Paso 5.3 — Entrenamiento de la CNN

# %%
# ── Entrenamiento de la CNN ─────────────────────────────────────
# TODO 10: define learning rate y épocas para la CNN.
seed_everything(42)

cnn_model = SimpleCNN().to(device)
cnn_optimizer = optim.Adam(cnn_model.parameters(), lr=1e-3)

cnn_history = fit_model(
    model=cnn_model,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_fn=loss_fn,
    optimizer=cnn_optimizer,
    device=device,
    epochs=150
)

plot_history(cnn_history, "Simple CNN")
# Out:
# Epoch 01/150 | train_loss=0.2260 | val_loss=0.1127 | train_acc=0.734 | val_acc=0.939
# Epoch 02/150 | train_loss=0.0947 | val_loss=0.0855 | train_acc=0.927 | val_acc=0.956
# Epoch 03/150 | train_loss=0.0779 | val_loss=0.0749 | train_acc=0.943 | val_acc=0.933
# Epoch 04/150 | train_loss=0.0687 | val_loss=0.0797 | train_acc=0.950 | val_acc=0.916
# Epoch 05/150 | train_loss=0.0672 | val_loss=0.0623 | train_acc=0.949 | val_acc=0.958
# Epoch 06/150 | train_loss=0.0590 | val_loss=0.0784 | train_acc=0.955 | val_acc=0.931
# Epoch 07/150 | train_loss=0.0570 | val_loss=0.0627 | train_acc=0.957 | val_acc=0.958
# Epoch 08/150 | train_loss=0.0550 | val_loss=0.0592 | train_acc=0.960 | val_acc=0.954
# Epoch 09/150 | train_loss=0.0522 | val_loss=0.0562 | train_acc=0.962 | val_acc=0.960
# Epoch 10/150 | train_loss=0.0512 | val_loss=0.0613 | train_acc=0.960 | val_acc=0.958
# Epoch 11/150 | train_loss=0.0503 | val_loss=0.0651 | train_acc=0.960 | val_acc=0.950
# Epoch 12/150 | train_loss=0.0502 | val_loss=0.0598 | train_acc=0.963 | val_acc=0.956
# Epoch 13/150 | train_loss=0.0448 | val_loss=0.0584 | train_acc=0.966 | val_acc=0.954
# Epoch 14/150 | train_loss=0.0449 | val_loss=0.0593 | train_acc=0.968 | val_acc=0.952
# Epoch 15/150 | train_loss=0.0441 | val_loss=0.0672 | train_acc=0.967 | val_acc=0.947
# Epoch 16/150 | train_loss=0.0415 | val_loss=0.0586 | train_acc=0.971 | val_acc=0.960
# Epoch 17/150 | train_loss=0.0391 | val_loss=0.0688 | train_acc=0.971 | val_acc=0.956
# Epoch 18/150 | train_loss=0.0407 | val_loss=0.0646 | train_acc=0.970 | val_acc=0.964
# Epoch 19/150 | train_loss=0.0408 | val_loss=0.0561 | train_acc=0.971 | val_acc=0.952
# Epoch 20/150 | train_loss=0.0428 | val_loss=0.0555 | train_acc=0.966 | val_acc=0.966
# Epoch 21/150 | train_loss=0.0373 | val_loss=0.0597 | train_acc=0.974 | val_acc=0.947
# Epoch 22/150 | train_loss=0.0370 | val_loss=0.0580 | train_acc=0.972 | val_acc=0.952
# Epoch 23/150 | train_loss=0.0359 | val_loss=0.0586 | train_acc=0.971 | val_acc=0.966
# Epoch 24/150 | train_loss=0.0358 | val_loss=0.0636 | train_acc=0.973 | val_acc=0.966
# Epoch 25/150 | train_loss=0.0375 | val_loss=0.0589 | train_acc=0.968 | val_acc=0.952
# Epoch 26/150 | train_loss=0.0313 | val_loss=0.0569 | train_acc=0.976 | val_acc=0.962
# Epoch 27/150 | train_loss=0.0312 | val_loss=0.0589 | train_acc=0.976 | val_acc=0.960
# Epoch 28/150 | train_loss=0.0306 | val_loss=0.0600 | train_acc=0.977 | val_acc=0.964
# Epoch 29/150 | train_loss=0.0313 | val_loss=0.0613 | train_acc=0.977 | val_acc=0.950
# Epoch 30/150 | train_loss=0.0293 | val_loss=0.0618 | train_acc=0.978 | val_acc=0.958
# Epoch 31/150 | train_loss=0.0309 | val_loss=0.0636 | train_acc=0.977 | val_acc=0.947
# Epoch 32/150 | train_loss=0.0272 | val_loss=0.0618 | train_acc=0.980 | val_acc=0.952
# Epoch 33/150 | train_loss=0.0293 | val_loss=0.0629 | train_acc=0.979 | val_acc=0.948
# Epoch 34/150 | train_loss=0.0308 | val_loss=0.0615 | train_acc=0.975 | val_acc=0.958
# Epoch 35/150 | train_loss=0.0279 | val_loss=0.0640 | train_acc=0.979 | val_acc=0.945
# Epoch 36/150 | train_loss=0.0265 | val_loss=0.0593 | train_acc=0.981 | val_acc=0.966
# Epoch 37/150 | train_loss=0.0255 | val_loss=0.0695 | train_acc=0.982 | val_acc=0.964
# Epoch 38/150 | train_loss=0.0258 | val_loss=0.0620 | train_acc=0.981 | val_acc=0.960
# Epoch 39/150 | train_loss=0.0220 | val_loss=0.0835 | train_acc=0.983 | val_acc=0.968
# Epoch 40/150 | train_loss=0.0216 | val_loss=0.0655 | train_acc=0.984 | val_acc=0.952
# Epoch 41/150 | train_loss=0.0214 | val_loss=0.0633 | train_acc=0.985 | val_acc=0.950
# Epoch 42/150 | train_loss=0.0234 | val_loss=0.0614 | train_acc=0.983 | val_acc=0.948
# Epoch 43/150 | train_loss=0.0215 | val_loss=0.0584 | train_acc=0.983 | val_acc=0.960
# Epoch 44/150 | train_loss=0.0173 | val_loss=0.0792 | train_acc=0.990 | val_acc=0.966
# Epoch 45/150 | train_loss=0.0181 | val_loss=0.0653 | train_acc=0.988 | val_acc=0.964
# Epoch 46/150 | train_loss=0.0185 | val_loss=0.0714 | train_acc=0.988 | val_acc=0.962
# Epoch 47/150 | train_loss=0.0186 | val_loss=0.0611 | train_acc=0.987 | val_acc=0.950
# Epoch 48/150 | train_loss=0.0166 | val_loss=0.0934 | train_acc=0.989 | val_acc=0.966
# Epoch 49/150 | train_loss=0.0143 | val_loss=0.0760 | train_acc=0.990 | val_acc=0.966
# Epoch 50/150 | train_loss=0.0153 | val_loss=0.0808 | train_acc=0.989 | val_acc=0.960
# Epoch 51/150 | train_loss=0.0141 | val_loss=0.0777 | train_acc=0.990 | val_acc=0.958
# Epoch 52/150 | train_loss=0.0143 | val_loss=0.0862 | train_acc=0.990 | val_acc=0.966
# Epoch 53/150 | train_loss=0.0144 | val_loss=0.0733 | train_acc=0.989 | val_acc=0.962
# Epoch 54/150 | train_loss=0.0133 | val_loss=0.0856 | train_acc=0.990 | val_acc=0.964
# Epoch 55/150 | train_loss=0.0162 | val_loss=0.0774 | train_acc=0.987 | val_acc=0.958
# Epoch 56/150 | train_loss=0.0131 | val_loss=0.0894 | train_acc=0.991 | val_acc=0.966
# Epoch 57/150 | train_loss=0.0132 | val_loss=0.0794 | train_acc=0.991 | val_acc=0.968
# Epoch 58/150 | train_loss=0.0121 | val_loss=0.1203 | train_acc=0.992 | val_acc=0.968
# Epoch 59/150 | train_loss=0.0112 | val_loss=0.0871 | train_acc=0.992 | val_acc=0.958
# Epoch 60/150 | train_loss=0.0166 | val_loss=0.0758 | train_acc=0.987 | val_acc=0.958
# Epoch 61/150 | train_loss=0.0123 | val_loss=0.0867 | train_acc=0.992 | val_acc=0.968
# Epoch 62/150 | train_loss=0.0099 | val_loss=0.0785 | train_acc=0.994 | val_acc=0.962
# Epoch 63/150 | train_loss=0.0118 | val_loss=0.0821 | train_acc=0.991 | val_acc=0.969
# Epoch 64/150 | train_loss=0.0102 | val_loss=0.1110 | train_acc=0.992 | val_acc=0.966
# Epoch 65/150 | train_loss=0.0088 | val_loss=0.0922 | train_acc=0.994 | val_acc=0.966
# Epoch 66/150 | train_loss=0.0096 | val_loss=0.0854 | train_acc=0.993 | val_acc=0.964
# Epoch 67/150 | train_loss=0.0073 | val_loss=0.0896 | train_acc=0.997 | val_acc=0.966
# Epoch 68/150 | train_loss=0.0069 | val_loss=0.1215 | train_acc=0.997 | val_acc=0.964
# Epoch 69/150 | train_loss=0.0073 | val_loss=0.0826 | train_acc=0.995 | val_acc=0.964
# Epoch 70/150 | train_loss=0.0064 | val_loss=0.0883 | train_acc=0.996 | val_acc=0.956
# Epoch 71/150 | train_loss=0.0077 | val_loss=0.1333 | train_acc=0.995 | val_acc=0.962
# Epoch 72/150 | train_loss=0.0079 | val_loss=0.0843 | train_acc=0.995 | val_acc=0.958
# Epoch 73/150 | train_loss=0.0073 | val_loss=0.0772 | train_acc=0.995 | val_acc=0.952
# Epoch 74/150 | train_loss=0.0068 | val_loss=0.0964 | train_acc=0.996 | val_acc=0.964
# Epoch 75/150 | train_loss=0.0046 | val_loss=0.1066 | train_acc=0.997 | val_acc=0.964
# Epoch 76/150 | train_loss=0.0052 | val_loss=0.1182 | train_acc=0.997 | val_acc=0.968
# Epoch 77/150 | train_loss=0.0069 | val_loss=0.1079 | train_acc=0.996 | val_acc=0.962
# Epoch 78/150 | train_loss=0.0062 | val_loss=0.0889 | train_acc=0.996 | val_acc=0.939
# Epoch 79/150 | train_loss=0.0135 | val_loss=0.0805 | train_acc=0.990 | val_acc=0.966
# Epoch 80/150 | train_loss=0.0100 | val_loss=0.0934 | train_acc=0.993 | val_acc=0.954
# Epoch 81/150 | train_loss=0.0065 | val_loss=0.0856 | train_acc=0.995 | val_acc=0.964
# Epoch 82/150 | train_loss=0.0035 | val_loss=0.0950 | train_acc=0.999 | val_acc=0.960
# Epoch 83/150 | train_loss=0.0030 | val_loss=0.1134 | train_acc=0.998 | val_acc=0.964
# Epoch 84/150 | train_loss=0.0029 | val_loss=0.1293 | train_acc=0.999 | val_acc=0.966
# Epoch 85/150 | train_loss=0.0030 | val_loss=0.1059 | train_acc=0.999 | val_acc=0.968
# Epoch 86/150 | train_loss=0.0025 | val_loss=0.1408 | train_acc=0.999 | val_acc=0.962
# Epoch 87/150 | train_loss=0.0028 | val_loss=0.1088 | train_acc=0.999 | val_acc=0.962
# Epoch 88/150 | train_loss=0.0027 | val_loss=0.1874 | train_acc=0.999 | val_acc=0.958
# Epoch 89/150 | train_loss=0.0023 | val_loss=0.1160 | train_acc=0.999 | val_acc=0.962
# Epoch 90/150 | train_loss=0.0019 | val_loss=0.1232 | train_acc=0.999 | val_acc=0.960
# Epoch 91/150 | train_loss=0.0020 | val_loss=0.1154 | train_acc=0.999 | val_acc=0.960
# Epoch 92/150 | train_loss=0.0020 | val_loss=0.1319 | train_acc=0.999 | val_acc=0.960
# Epoch 93/150 | train_loss=0.0018 | val_loss=0.1120 | train_acc=0.999 | val_acc=0.962
# Epoch 94/150 | train_loss=0.0043 | val_loss=0.1262 | train_acc=0.997 | val_acc=0.966
# Epoch 95/150 | train_loss=0.0061 | val_loss=0.1791 | train_acc=0.995 | val_acc=0.960
# Epoch 96/150 | train_loss=0.0035 | val_loss=0.1153 | train_acc=0.998 | val_acc=0.966
# Epoch 97/150 | train_loss=0.0031 | val_loss=0.1112 | train_acc=0.998 | val_acc=0.956
# Epoch 98/150 | train_loss=0.0060 | val_loss=0.1209 | train_acc=0.995 | val_acc=0.964
# Epoch 99/150 | train_loss=0.0024 | val_loss=0.1147 | train_acc=0.999 | val_acc=0.958
# Epoch 100/150 | train_loss=0.0015 | val_loss=0.1313 | train_acc=0.999 | val_acc=0.958
# Epoch 101/150 | train_loss=0.0011 | val_loss=0.1402 | train_acc=0.999 | val_acc=0.964
# Epoch 102/150 | train_loss=0.0009 | val_loss=0.1335 | train_acc=1.000 | val_acc=0.964
# Epoch 103/150 | train_loss=0.0012 | val_loss=0.1589 | train_acc=0.999 | val_acc=0.962
# Epoch 104/150 | train_loss=0.0009 | val_loss=0.1424 | train_acc=1.000 | val_acc=0.962
# Epoch 105/150 | train_loss=0.0008 | val_loss=0.1468 | train_acc=1.000 | val_acc=0.964
# Epoch 106/150 | train_loss=0.0007 | val_loss=0.1462 | train_acc=1.000 | val_acc=0.962
# Epoch 107/150 | train_loss=0.0007 | val_loss=0.1349 | train_acc=1.000 | val_acc=0.962
# Epoch 108/150 | train_loss=0.0006 | val_loss=0.1649 | train_acc=1.000 | val_acc=0.964
# Epoch 109/150 | train_loss=0.0007 | val_loss=0.1637 | train_acc=1.000 | val_acc=0.960
# Epoch 110/150 | train_loss=0.0005 | val_loss=0.1450 | train_acc=1.000 | val_acc=0.962
# Epoch 111/150 | train_loss=0.0004 | val_loss=0.1612 | train_acc=1.000 | val_acc=0.960
# Epoch 112/150 | train_loss=0.0005 | val_loss=0.1927 | train_acc=1.000 | val_acc=0.958
# Epoch 113/150 | train_loss=0.0004 | val_loss=0.1662 | train_acc=1.000 | val_acc=0.962
# Epoch 114/150 | train_loss=0.0004 | val_loss=0.1607 | train_acc=1.000 | val_acc=0.960
# Epoch 115/150 | train_loss=0.0003 | val_loss=0.1926 | train_acc=1.000 | val_acc=0.958
# Epoch 116/150 | train_loss=0.0003 | val_loss=0.1649 | train_acc=1.000 | val_acc=0.960
# Epoch 117/150 | train_loss=0.0004 | val_loss=0.1795 | train_acc=1.000 | val_acc=0.960
# Epoch 118/150 | train_loss=0.0004 | val_loss=0.1773 | train_acc=1.000 | val_acc=0.958
# Epoch 119/150 | train_loss=0.0003 | val_loss=0.1746 | train_acc=1.000 | val_acc=0.960
# Epoch 120/150 | train_loss=0.0002 | val_loss=0.1920 | train_acc=1.000 | val_acc=0.958
# Epoch 121/150 | train_loss=0.0209 | val_loss=0.1175 | train_acc=0.988 | val_acc=0.939
# Epoch 122/150 | train_loss=0.0226 | val_loss=0.2275 | train_acc=0.983 | val_acc=0.952
# Epoch 123/150 | train_loss=0.0146 | val_loss=0.1144 | train_acc=0.989 | val_acc=0.964
# Epoch 124/150 | train_loss=0.0041 | val_loss=0.1007 | train_acc=0.997 | val_acc=0.956
# Epoch 125/150 | train_loss=0.0022 | val_loss=0.1137 | train_acc=0.999 | val_acc=0.962
# Epoch 126/150 | train_loss=0.0013 | val_loss=0.1490 | train_acc=1.000 | val_acc=0.960
# Epoch 127/150 | train_loss=0.0009 | val_loss=0.1503 | train_acc=1.000 | val_acc=0.962
# Epoch 128/150 | train_loss=0.0007 | val_loss=0.1712 | train_acc=1.000 | val_acc=0.960
# Epoch 129/150 | train_loss=0.0007 | val_loss=0.1576 | train_acc=1.000 | val_acc=0.960
# Epoch 130/150 | train_loss=0.0005 | val_loss=0.1520 | train_acc=1.000 | val_acc=0.960
# Epoch 131/150 | train_loss=0.0005 | val_loss=0.1627 | train_acc=1.000 | val_acc=0.960
# Epoch 132/150 | train_loss=0.0005 | val_loss=0.1550 | train_acc=1.000 | val_acc=0.960
# Epoch 133/150 | train_loss=0.0004 | val_loss=0.1652 | train_acc=1.000 | val_acc=0.958
# Epoch 134/150 | train_loss=0.0004 | val_loss=0.1638 | train_acc=1.000 | val_acc=0.960
# Epoch 135/150 | train_loss=0.0004 | val_loss=0.1602 | train_acc=1.000 | val_acc=0.960
# Epoch 136/150 | train_loss=0.0004 | val_loss=0.1566 | train_acc=1.000 | val_acc=0.960
# Epoch 137/150 | train_loss=0.0003 | val_loss=0.1845 | train_acc=1.000 | val_acc=0.954
# Epoch 138/150 | train_loss=0.0003 | val_loss=0.1645 | train_acc=1.000 | val_acc=0.960
# Epoch 139/150 | train_loss=0.0003 | val_loss=0.1772 | train_acc=1.000 | val_acc=0.960
# Epoch 140/150 | train_loss=0.0003 | val_loss=0.1600 | train_acc=1.000 | val_acc=0.958
# Epoch 141/150 | train_loss=0.0003 | val_loss=0.1630 | train_acc=1.000 | val_acc=0.958
# Epoch 142/150 | train_loss=0.0002 | val_loss=0.1667 | train_acc=1.000 | val_acc=0.958
# Epoch 143/150 | train_loss=0.0002 | val_loss=0.1742 | train_acc=1.000 | val_acc=0.960
# Epoch 144/150 | train_loss=0.0002 | val_loss=0.1699 | train_acc=1.000 | val_acc=0.958
# Epoch 145/150 | train_loss=0.0002 | val_loss=0.1771 | train_acc=1.000 | val_acc=0.960
# Epoch 146/150 | train_loss=0.0002 | val_loss=0.1740 | train_acc=1.000 | val_acc=0.958
# Epoch 147/150 | train_loss=0.0002 | val_loss=0.1773 | train_acc=1.000 | val_acc=0.958
# Epoch 148/150 | train_loss=0.0002 | val_loss=0.1775 | train_acc=1.000 | val_acc=0.960
# Epoch 149/150 | train_loss=0.0002 | val_loss=0.1767 | train_acc=1.000 | val_acc=0.960
# Epoch 150/150 | train_loss=0.0002 | val_loss=0.1920 | train_acc=1.000 | val_acc=0.960

# %% [markdown]
# ### Paso 5.4 — Comparación visual de curvas

# %%
# ── Comparación de curvas MLP vs CNN ────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(mlp_history["val_loss"], marker="o", label="MLP")
axes[0].plot(cnn_history["val_loss"], marker="o", label="CNN")
axes[0].set_title("Validation loss")
axes[0].set_xlabel("Época")
axes[0].set_ylabel("Loss")
axes[0].legend()

axes[1].plot(mlp_history["val_acc"], marker="o", label="MLP")
axes[1].plot(cnn_history["val_acc"], marker="o", label="CNN")
axes[1].set_title("Validation accuracy")
axes[1].set_xlabel("Época")
axes[1].set_ylabel("Accuracy")
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Paso 5.5 — Interpretación CNN vs MLP
#
# **📝 Tu respuesta (edita esta celda):**
#
# > **TODO:** responde con 2–3 líneas por pregunta. Usa conceptos de CNN, MLP y métricas clínicas.
#
# **1. ¿La CNN mejora frente al MLP? Usa tus curvas y métricas, no solo accuracy.**
# _Sí, Aunque el MLP logra el mínimo loss y una mayor eficiencia computacional. Sin embargo, muestra tener la ventaja de una mayor robustez, pues se puede observar en la curva de loss y accuracy que mlp tuvo una variación infrecuente pero alta, mientras que cnn tuvo una frecuente pero baja_
#
# **2. ¿Qué aporta la convolución que no aporta el MLP al aplanar la imagen?**
# _La relación espacial y de distancia entre los pixeles, lo que ayuda a identificar las estructuras de la imagen de forma más general y generar salidas más dependientes de un contexto localizado._
#
# **3. Si la CNN tiene mejor AUC o especificidad, pero menor sensibilidad con umbral 0.5, ¿cómo interpretarías ese resultado?**
# _Se podría interpretar como que CNN permite una mejor generalización pero esto viene a costas de relaciones específicas entre pixeles a largas distancias._
#
# **4. ¿Qué factores podrían explicar que una CNN simple no mejore mucho frente al baseline?**
# _Podría ser debido a que más allá de interpretar las estructuras y formas, el modelo mlp está aprovechando correlaciones entre atributos inesperados y la neumonía. Esto se exacerba por el hecho que las imágenes están bastante pixeleadas y las capacidades de las cnn no son del todo aprovechadas._

# %% [markdown]
# ---
# # PARTE 4 — Métricas clínicas y análisis de errores
# ## Ejercicio 6 — Evaluación final
#
# <div style='background:#fff3e0; padding:8px 14px; border-left:4px solid #e65100; border-radius:4px; margin:8px 0'>
# 📚 <b>TAREA</b> — completa esto antes de la siguiente clase
# </div>

# %% [markdown]
# ### Paso 6.1 — Predicción de probabilidades

# %%
# ── Predicción de probabilidades en test ────────────────────────
# TODO 11: convierte logits en probabilidades con sigmoid.
@torch.no_grad()
def predict_proba(model, loader, device):
    model.eval()

    all_probs = []
    all_true = []

    for X_batch, y_batch in loader:
        X_batch = X_batch.to(device)
        logits = model(X_batch)
        probs = torch.sigmoid(logits)

        all_probs.extend(probs)
        all_true.extend(y_batch.numpy().reshape(-1).astype(int))

    return np.array(all_true), np.array(all_probs)

y_test_true, mlp_prob = predict_proba(mlp_model, test_loader, device)
_, cnn_prob = predict_proba(cnn_model, test_loader, device)

print("Primeras probabilidades MLP:", mlp_prob[:5])
print("Primeras probabilidades CNN:", cnn_prob[:5])
# Out:
# Primeras probabilidades MLP: [[1.000000e+00]
#  [1.000000e+00]
#  [9.999999e-01]
#  [1.785611e-07]
#  [1.000000e+00]]
# Primeras probabilidades CNN: [[1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [3.0971245e-15]
#  [1.0000000e+00]]

# %% [markdown]
# ### Paso 6.2 — Métricas clínicas

# %%
# ── Métricas clínicas ───────────────────────────────────────────
# TODO 12: completa sensibilidad, especificidad y precisión.
def clinical_metrics(y_true, y_prob, threshold=0.5, model_name="model"):
    y_pred = (y_prob >= threshold).astype(int)

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()

    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else np.nan
    specificity = tn / (tn + fp) if (tn + fp) > 0 else np.nan
    precision   = tp / (tp + fp) if (tp + fp) > 0 else np.nan

    return {
        "model": model_name,
        "threshold": threshold,
        "accuracy": accuracy_score(y_true, y_pred),
        "sensitivity_recall": sensitivity,
        "specificity": specificity,
        "precision": precision,
        "f1": f1_score(y_true, y_pred),
        "roc_auc": roc_auc_score(y_true, y_prob),
        "TN": tn, "FP": fp, "FN": fn, "TP": tp
    }

results = pd.DataFrame([
    clinical_metrics(y_test_true, mlp_prob, threshold=0.5, model_name="MLP"),
    clinical_metrics(y_test_true, cnn_prob, threshold=0.5, model_name="CNN")
])

display(results)
# Out:
#   model  threshold  accuracy  sensitivity_recall  specificity  precision  \
# 0   MLP        0.5  0.866987            0.984615     0.670940   0.832972
# 1   CNN        0.5  0.865385            0.992308     0.653846   0.826923
#
#          f1   roc_auc   TN  FP  FN   TP
# 0  0.902468  0.928019  157  77   6  384
# 1  0.902098  0.912316  153  81   3  387

# %% [markdown]
# ### Paso 6.3 — Matrices de confusión

# %%
# ── Matrices de confusión ───────────────────────────────────────
def plot_confusion(y_true, y_prob, threshold, title):
    y_pred = (y_prob >= threshold).astype(int)
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])

    fig, ax = plt.subplots(figsize=(5, 4))
    sns.heatmap(
        cm, annot=True, fmt="d", cbar=False,
        xticklabels=["Pred Normal", "Pred Pneumonia"],
        yticklabels=["Real Normal", "Real Pneumonia"],
        ax=ax
    )
    ax.set_title(title)
    ax.set_xlabel("Predicción")
    ax.set_ylabel("Real")
    plt.show()

plot_confusion(y_test_true, mlp_prob, threshold=0.5, title="MLP — Matriz de confusión")
plot_confusion(y_test_true, cnn_prob, threshold=0.5, title="CNN — Matriz de confusión")

# %% [markdown]
# ### Paso 6.4 — Curva ROC

# %%
# ── Curva ROC ───────────────────────────────────────────────────
fpr_mlp, tpr_mlp, _ = roc_curve(y_test_true, mlp_prob)
fpr_cnn, tpr_cnn, _ = roc_curve(y_test_true, cnn_prob)

auc_mlp = roc_auc_score(y_test_true, mlp_prob)
auc_cnn = roc_auc_score(y_test_true, cnn_prob)

fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(fpr_mlp, tpr_mlp, label=f"MLP AUC={auc_mlp:.3f}")
ax.plot(fpr_cnn, tpr_cnn, label=f"CNN AUC={auc_cnn:.3f}")
ax.plot([0, 1], [0, 1], "--", color=UPCH_GRAY)
ax.set_title("Curva ROC — detección de neumonía")
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate / Sensibilidad")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ### Paso 6.5 — Análisis de umbral para la CNN
#
# Un modelo produce probabilidades, pero la etiqueta final depende del **umbral de decisión**. En problemas clínicos, este umbral no siempre debe ser 0.5.
#
# **Pregunta guía:** si el objetivo clínico es reducir falsos negativos, ¿qué umbral recomendarías y qué costo tendría en falsos positivos?

# %%
# ── Análisis de umbral ──────────────────────────────────────────
# TODO 13: prueba tres umbrales: bajo, estándar y alto.
threshold_rows = []
for th in [0.3, 0.5, 0.8]:
    threshold_rows.append(
        clinical_metrics(y_test_true, cnn_prob, threshold=th, model_name="CNN")
    )

threshold_df = pd.DataFrame(threshold_rows)
display(threshold_df[[
    "model", "threshold", "accuracy", "sensitivity_recall",
    "specificity", "precision", "f1", "FN", "FP", "TP", "TN"
]])
# Out:
#   model  threshold  accuracy  sensitivity_recall  specificity  precision  \
# 0   CNN        0.3  0.849359            0.992308     0.611111   0.809623
# 1   CNN        0.5  0.865385            0.992308     0.653846   0.826923
# 2   CNN        0.8  0.876603            0.989744     0.688034   0.840959
#
#          f1  FN  FP   TP   TN
# 0  0.891705   3  91  387  143
# 1  0.902098   3  81  387  153
# 2  0.909305   4  73  386  161

# %% [markdown]
# ### Paso 6.6 — Visualización de errores

# %%
# ── Visualización de falsos negativos y falsos positivos ────────
@torch.no_grad()
def collect_images_probs(model, loader, device):
    model.eval()

    images = []
    y_true = []
    y_prob = []

    for X_batch, y_batch in loader:
        logits = model(X_batch.to(device))
        probs = torch.sigmoid(logits).cpu().numpy().reshape(-1)

        images.append(X_batch.cpu())
        y_true.extend(y_batch.numpy().reshape(-1).astype(int))
        y_prob.extend(probs)

    images = torch.cat(images, dim=0)
    return images, np.array(y_true), np.array(y_prob)


def plot_errors(model, loader, device, error_type="FN", threshold=0.5, max_images=8):
    images, y_true, y_prob = collect_images_probs(model, loader, device)
    y_pred = (y_prob >= threshold).astype(int)

    if error_type == "FN":
        idxs = np.where((y_true == 1) & (y_pred == 0))[0]
        title = "Falsos negativos: neumonía clasificada como normal"
    elif error_type == "FP":
        idxs = np.where((y_true == 0) & (y_pred == 1))[0]
        title = "Falsos positivos: normal clasificado como neumonía"
    else:
        raise ValueError("error_type debe ser 'FN' o 'FP'")

    if len(idxs) == 0:
        print(f"No se encontraron errores tipo {error_type} con threshold={threshold}.")
        return

    chosen = idxs[:max_images]

    fig, axes = plt.subplots(1, len(chosen), figsize=(2 * len(chosen), 2.5))
    if len(chosen) == 1:
        axes = [axes]

    for ax, idx in zip(axes, chosen):
        ax.imshow(unnormalize_img(images[idx]), cmap="gray")
        ax.axis("off")
        ax.set_title(f"p={y_prob[idx]:.2f}")

    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

plot_errors(cnn_model, test_loader, device, error_type="FN", threshold=0.5, max_images=8)
plot_errors(cnn_model, test_loader, device, error_type="FP", threshold=0.5, max_images=8)

# %% [markdown]
# ### Paso 6.7 — Interpretación final
#
# **📝 Tu respuesta (edita esta celda):**
#
# > **TODO:** responde con 2–3 líneas por pregunta. Usa conceptos de CNN, MLP y métricas clínicas.
#
# **1. ¿Qué modelo elegirías como apoyo diagnóstico: MLP o CNN? Justifica con métricas.**
# _Elegiría el CNN debido a su recall más elevado, aunque su presición no sea tan alta._
#
# **2. ¿Qué métrica priorizarías si quieres reducir neumonías no detectadas?**
# _Recall._
#
# **3. ¿Qué pasa con falsos positivos y falsos negativos al bajar el umbral?**
# _Los falsos positivos aumentan, los falsos negativos disminuyen._
#
# **4. ¿Qué umbral recomendarías para la CNN si el objetivo es reducir falsos negativos? Justifica con la tabla.**
# _El umbral más bajo, debido a que debería aumentar el recall, si bien en esta caso no fue necesario._
#
# **5. ¿Por qué este modelo no debe interpretarse como reemplazo del médico?**
# _Debido a que es susceptible a basarse en el común denominador y fallar en casos mas particulares, además de la posibilidad de que no solo se esté analizando la zona afectada, si no el resto de la imagen para llegar a la conclusión cuando no sería buena práctica hacerlo._

# %% [markdown]
# ## Checklist de entrega
#
# Antes de entregar, verifica que tu notebook incluya:
#
# - [ ] Respuestas conceptuales completas sobre MLP vs CNN, convolución, pooling y clasificación binaria.
# - [ ] Carga correcta de PneumoniaMNIST con splits train/validation/test.
# - [ ] Visualización de ejemplos de ambas clases.
# - [ ] Creación correcta de DataLoaders con mini-batches.
# - [ ] Definición funcional de `FlattenMLP`.
# - [ ] Definición funcional de `SimpleCNN`.
# - [ ] Loop explícito de PyTorch con `forward`, `loss`, `zero_grad`, `backward`, `step`.
# - [ ] Curvas de pérdida y accuracy para MLP y CNN.
# - [ ] Evaluación en test con matriz de confusión, sensibilidad, especificidad, precisión, F1 y ROC-AUC.
# - [ ] Análisis de umbral para la CNN.
# - [ ] Discusión clínica de falsos negativos y falsos positivos.
# - [ ] Conclusión comparando MLP vs CNN.
